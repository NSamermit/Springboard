# %% [markdown]
# # Springboard Capstone 2:
# ## Covid-19 Wastewater Surveillance Prediction
# ### Author: Nantawat Samermit

# %% [markdown]
# ## Executive Summary
#
# ### Problem:
# The Sars-CoV-19 or 'Covid-19' virus is an ongoing pandemic. Businesses and communities are being affected with each wave. Wastewater surveillance is a non-invasive way to measure mRNA concentrations of the virus.
#
# ### Exploratory Research Question:
# Can we use the viral concentration surveilled from wastewater to predict a surge?
#
#
# ### Methods
#     Rationale for Method
#
# ### Results
#
# ### Implications

# %% [markdown]
# # Data Scraping (Unit 7.2)
# I'll be scraping three datasets.
#
# The first is from the Cambridge MA wastewater data archive. It is listed as JSON, which I will convert to a pandas DataFrame.
#
# The URL is here: 'https://data.cambridgema.gov/resource/ayt4-g2ye.json'
#
#
# The second dataset is from Massachusetts Department of Health.
#
# The URL is here: 'https://www.mass.gov/doc/covid-19-raw-data-june-15-2021/download'
#
# The third dataset is from Biobot's Github: https://github.com/biobotanalytics/covid19-wastewater-data/blob/master/wastewater_by_county.csv
#
# I downloaded the third dataset from Github and added it to the Biobot Data folder.

# %%
#import relevant modules for data wrangling - keep on adding as needed
import pandas as pd
import json, requests
import fuzzywuzzy 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn import preprocessing

# %% [markdown]
# ## Notes regarding Massachusetts Data
# After some attempts, it seems the Massachusetts dataset is a multi-page csv, and it isn't easily accessible.
#
# I will have to use BeautifulSoup to isolate the link to the excel file.

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen, Request

# %%
# Use BS to identify/isolate the html "class" pointing to the href of the .xls 
#class and "ma__download-link__file-link" was identified by inspecting the page's elements in chrome
source = requests.get("https://www.mass.gov/doc/covid-19-raw-data-july-29-2021")
BeautifulSoup(source.content).find("a", {"class":"ma__download-link__file-link"}).get("href")
# Out:
# '/doc/covid-19-raw-data-july-29-2021/download'

# %% [markdown]
# BeautifulSoup has isloated the href link for the .xls spreadsheet.
#
# It is here: https://www.mass.gov/doc/covid-19-raw-data-july-29-2021/download

# %% [markdown]
# ## Scrape, Download, and Save datasets
# I will write a function to scrape, convert, and save both datasets to my directory as pickle files.

# %%
#Luka states it is easier (and acceptable) to just download the files to local path. 

#For the mass.gov dataset, it has mulitiple sheets, so it isolates the intended sheet. (not dynamic, ikr)

def get_sources(source_list):
    '''
    this function takes a list of urls, ID's their format, requests dataset from source,
    converts data into a dataframe, then saves it as a pickled file.
    '''
    for counter, source in enumerate(source_list):
        name = str(counter) + '_df.pkl'

        if source.endswith('.json'):
            response = requests.get(source)
            data = response.json()
            json_df = pd.DataFrame(data)            
            json_df.to_pickle(name)
            
        
        elif source.endswith('.csv'):
            csv = pd.read_csv(source, engine='python')
            csv.to_pickle(name)
            
        else:
            response = requests.get(source, allow_redirects=True)
            with open('excel_data.xlsx', 'wb') as file:
                file.write(response.content)
            
            #using pd.read_excel on a multi-spreadsheet xls yields a dictionary
            excel_dict = pd.read_excel('excel_data.xlsx', sheet_name=None)
            name = str(counter) + '_df.pkl'
            #can ID sheetnames by evaluating keys
            #print(excel_dict.keys())
            if len(excel_dict.keys()) > 1:
                print('There are more than one sheet in this .csv file.','\n',
                      source, '\n', excel_dict.keys())
                myInput = input('Which of these sheets do  you want to use?')
                #print(myInput)
                excel_specified_sheet = excel_dict[myInput]
                excel_specified_sheet.to_pickle(name)
            else:
                excel_dict.to_pickle(name)
            
        print(name,' created using this source', source)

# %%
sources = ['https://data.cambridgema.gov/resource/ayt4-g2ye.json', 
           'https://www.mass.gov/doc/covid-19-raw-data-july-29-2021/download',
           'Biobot Data/wastewater_by_county.csv' 
          ]

#old_source = 'https://www.mass.gov/doc/covid-19-raw-data-june-15-2021/download'

get_sources(sources)
# Out:
# 0_df.pkl  created using this source https://data.cambridgema.gov/resource/ayt4-g2ye.json
# There are more than one sheet in this .csv file.
#  https://www.mass.gov/doc/covid-19-raw-data-july-29-2021/download
#  dict_keys(['Data Documentation', 'Weekly_Town_Reference', 'Age Means Last2Weeks', 'AgeLast2Weeks', 'Cases (Report Date)', 'CasesbyAge', 'CasesByDate (Test Date)', 'CasesByDate_Probable', 'County_Daily', 'County_Weekly', 'CountyDeaths', 'DateofDeath', 'DeathsReported (Report Date)', 'DeathCharacteristics', 'HigherEd_CasesandTests', 'HospBedAvailable-Regional', 'HospBed-Hospital COVID Census', 'Hospitalization from Hospitals', 'LTC Facilities', 'RaceEthnicityLast2Weeks', 'SexLast2Weeks', 'Testing2 (Report Date)', 'TestingByDate (Test Date)', 'TestingPosByAge', 'Weekly_City_Town', 'Weekly_Statewide', 'Clusters', 'Isolation and Quarantine', 'Contact Tracing', 'CTC workforce', 'Counts by Specimen Date (Sero)'])
# Which of these sheets do  you want to use?Weekly_City_Town
# 1_df.pkl  created using this source https://www.mass.gov/doc/covid-19-raw-data-july-29-2021/download
# 2_df.pkl  created using this source Biobot Data/wastewater_by_county.csv

# %% [markdown]
# ## Use pickle to confirm the saved files can be loaded in Jupyter

# %%
import pickle

# %%
#should use context manager to load pickles 
# Don't forget to state 'rb' param or will get an Unicode Error.

    
with open('0_df.pkl', 'rb') as f:
    Cambridge_df = pickle.load(f)
    
with open('1_df.pkl', 'rb') as f:
    Mass_df = pickle.load(f)

with open('2_df.pkl', 'rb') as f:
    Biobot_df = pickle.load(f)

# %%
#testing both dataframes
Cambridge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293 entries, 0 to 292
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   date                          293 non-null    object
#  1   mwra_concentration            293 non-null    object
#  2   mwra_7dayaverage              293 non-null    object
#  3   concentration_mid_cambridge   293 non-null    object
#  4   concentration_east_cambridge  293 non-null    object
#  5   concentration_cambridgeport   293 non-null    object
#  6   concentration_north_west      293 non-null    object
#  7   highci_mid_cambridge          293 non-null    object
#  8   highci_east_cambridge         293 non-null    object
#  9   highci_cambridgeport          293 non-null    object
#  10  highci_north_west_cambridge   293 non-null    object
#  11  lowci_mid_cambridge           293 non-null    object
#  12  lowci_east_cambridge          293 non-null    object
#  13  lowci_cambridgeport           293 non-null    object
#  14  lowci_north_west_cambridge    293 non-null    object
# dtypes: object(15)
# memory usage: 34.5+ KB

# %%
Mass_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11296 entries, 0 to 11295
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   City/Town                   11296 non-null  object
#  1   County                      11296 non-null  object
#  2   Population                  11296 non-null  object
#  3   Total Case Counts           11296 non-null  object
#  4   Two Week Case Counts        11296 non-null  object
#  5   Average Daily Rate          11296 non-null  object
#  6   Color                       9495 non-null   object
#  7   Change in Last Week         11296 non-null  object
#  8   Total Tests                 11296 non-null  int64
#  9   Total Tests Last Two Weeks  11295 non-null  float64
#  10  Total Positive Tests        11295 non-null  float64
#  11  Percent Positivity          11295 non-null  object
#  12  Change Since Last Week      11296 non-null  object
#  13  Testing Rate                11292 non-null  object
#  14  Report Date                 11296 non-null  datetime64[ns]
#  15  Start_Date                  11296 non-null  datetime64[ns]
#  16  End_Date                    11296 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), float64(2), int64(1), object(11)
# memory usage: 1.5+ MB

# %%
Biobot_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1267 entries, 0 to 1266
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   sampling_week                             1267 non-null   object
#  1   normalized_concentration_rolling_average  1267 non-null   float64
#  2   population                                1267 non-null   object
#  3   region                                    1267 non-null   object
#  4   state                                     1267 non-null   object
#  5   county_fips_code                          1267 non-null   int64
#  6   county_name                               1267 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 69.4+ KB

# %% [markdown]
# # Data Wrangling (Unit 7.2)
# Explore the dataset. Understand the datatypes for the various columns, and confirm that there are no missing values.

# %% [markdown]
# ## Cambridge Data

# %%
Cambridge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293 entries, 0 to 292
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   date                          293 non-null    object
#  1   mwra_concentration            293 non-null    object
#  2   mwra_7dayaverage              293 non-null    object
#  3   concentration_mid_cambridge   293 non-null    object
#  4   concentration_east_cambridge  293 non-null    object
#  5   concentration_cambridgeport   293 non-null    object
#  6   concentration_north_west      293 non-null    object
#  7   highci_mid_cambridge          293 non-null    object
#  8   highci_east_cambridge         293 non-null    object
#  9   highci_cambridgeport          293 non-null    object
#  10  highci_north_west_cambridge   293 non-null    object
#  11  lowci_mid_cambridge           293 non-null    object
#  12  lowci_east_cambridge          293 non-null    object
#  13  lowci_cambridgeport           293 non-null    object
#  14  lowci_north_west_cambridge    293 non-null    object
# dtypes: object(15)
# memory usage: 34.5+ KB

# %%
Cambridge_df.describe()
# Out:
#                            date mwra_concentration mwra_7dayaverage  \
# count                       293                293              293
# unique                      293                232              214
# top     2021-04-13T00:00:00.000                                  20
# freq                          1                 14                6
#
#        concentration_mid_cambridge concentration_east_cambridge  \
# count                          293                          293
# unique                          30                           35
# top
# freq                           258                          256
#
#        concentration_cambridgeport concentration_north_west  \
# count                          293                      293
# unique                          27                       34
# top
# freq                           260                      256
#
#        highci_mid_cambridge highci_east_cambridge highci_cambridgeport  \
# count                   293                   293                  293
# unique                   30                    35                   27
# top
# freq                    258                   256                  260
#
#        highci_north_west_cambridge lowci_mid_cambridge lowci_east_cambridge  \
# count                          293                 293                  293
# unique                          34                  30                   35
# top
# freq                           256                 258                  256
#
#        lowci_cambridgeport lowci_north_west_cambridge
# count                  293                        293
# unique                  27                         34
# top
# freq                   260                        256

# %% [markdown]
# # Note to myself:
# For my own review!
#
# Column Definitions:
# Date - sample date for 24 hour composite sample
#
#
# MWRA_Concentration - Normalized SARS-CoV2 RNA Copies per ML collected during sampling period.
#
#
# MWRA_7DayAverage - 7 day rolling average for Normalized SARS-CoV2 RNA Copies per ML collected during sampling period.
#
#
# Concentration_* - Normalized SARS-CoV2 RNA Copies per ML collected during sampling period.
#
#
# highci_* - Upper Limit on Confidence Interval for Normalized SARS-CoV2 RNA Copies per ML collected during sampling period.
#
#
# lowci_* - Lower Limit on Confidence Interval for Normalized SARS-CoV2 RNA Copies per ML collected during sampling period.
# * means there are multiple columns with this prefix which share the same definition - Nantawat
#
# A refresher on confidence interval limits - https://bit.ly/3vtuI7h

# %% [markdown]
# ## Features observations:
# 1. All the features pf Cambridge_df are object dtypes.
# 2. describe() states they (15 features) are all non-null values. Let's confirm that.

# %%
#This confirms that none of the features contain null values. 
Cambridge_df.isnull().sum()
# Out:
# date                            0
# mwra_concentration              0
# mwra_7dayaverage                0
# concentration_mid_cambridge     0
# concentration_east_cambridge    0
# concentration_cambridgeport     0
# concentration_north_west        0
# highci_mid_cambridge            0
# highci_east_cambridge           0
# highci_cambridgeport            0
# highci_north_west_cambridge     0
# lowci_mid_cambridge             0
# lowci_east_cambridge            0
# lowci_cambridgeport             0
# lowci_north_west_cambridge      0
# dtype: int64

# %%
#This will show that although isnull().sum() returns 0 null values, the cells look blank!
Cambridge_df.head(5)
# Out:
#                       date mwra_concentration mwra_7dayaverage  \
# 0  2020-10-01T00:00:00.000                                  31
# 1  2020-10-02T00:00:00.000                 34               31
# 2  2020-10-03T00:00:00.000                                  31
# 3  2020-10-04T00:00:00.000                                  31
# 4  2020-10-05T00:00:00.000                 38               30
#
#   concentration_mid_cambridge concentration_east_cambridge  \
# 0
# 1
# 2
# 3
# 4
#
#   concentration_cambridgeport concentration_north_west highci_mid_cambridge  \
# 0
# 1
# 2
# 3
# 4
#
#   highci_east_cambridge highci_cambridgeport highci_north_west_cambridge  \
# 0
# 1
# 2
# 3
# 4
#
#   lowci_mid_cambridge lowci_east_cambridge lowci_cambridgeport  \
# 0
# 1
# 2
# 3
# 4
#
#   lowci_north_west_cambridge
# 0
# 1
# 2
# 3
# 4

# %%
#Just incase I need to examine this data one day... 
Cambridge_non_blank_data = pd.DataFrame(Cambridge_df.loc[Cambridge_df['concentration_mid_cambridge'] != ''])

# %% [markdown]
# ### This does not pass the stench test! mwra_concentration is not 100% non-null

# %%
#Check these blank cells to confirm they are 'filled' with whitespaces
Cambridge_df['mwra_concentration'][0] == ''
# Out:
# True

# %%
#create a method using the logic from the cell above to check for blank cells
def blank_check(df):
    ''' A method to check my column cells from a pandas DataFrame for whitespace blanks.'''
    return dict(zip(df.columns, [(df[x] == '').sum() for x in df.columns]))

# %%
blank_check(Cambridge_df)
# Out:
# {'date': 0,
#  'mwra_concentration': 14,
#  'mwra_7dayaverage': 4,
#  'concentration_mid_cambridge': 258,
#  'concentration_east_cambridge': 256,
#  'concentration_cambridgeport': 260,
#  'concentration_north_west': 256,
#  'highci_mid_cambridge': 258,
#  'highci_east_cambridge': 256,
#  'highci_cambridgeport': 260,
#  'highci_north_west_cambridge': 256,
#  'lowci_mid_cambridge': 258,
#  'lowci_east_cambridge': 256,
#  'lowci_cambridgeport': 260,
#  'lowci_north_west_cambridge': 256}

# %% [markdown]
# ### Looking at how many 'blank' whitespace cells those features have, I think it is prudent to drop them first

# %%
kept_features = ['date', 'mwra_concentration', 'mwra_7dayaverage']
Cambridge_df.drop(columns=Cambridge_df.columns.difference(kept_features), inplace=True)

# %%
#confirm those columns were dropped
Cambridge_df.describe()
# Out:
#                            date mwra_concentration mwra_7dayaverage
# count                       293                293              293
# unique                      293                232              214
# top     2021-04-13T00:00:00.000                                  20
# freq                          1                 14                6

# %%
#confirm how many blank cells to wrangle
blank_check(Cambridge_df)
# Out:
# {'date': 0, 'mwra_concentration': 14, 'mwra_7dayaverage': 4}

# %% [markdown]
# ### At this point - Choose:
# 1. Drop those rows with blank columns
# 2. Impute them with something
#
#     A: Can be the mwra_7dayaverage
#
#     B: Can be a front-fill method
#
#     C:  Can be a back-fill method

# %% [markdown]
# #### I chose option 2, and I want to fill with the mwra_7dayaverage where I can.

# %%
#change 'date' feature into a datetime and assign to index
Cambridge_df.date = pd.to_datetime(Cambridge_df.date)
Cambridge_df.set_index('date', inplace=True)

# %%
#blank check before the whitespace replacement
blank_check(Cambridge_df)
# Out:
# {'mwra_concentration': 14, 'mwra_7dayaverage': 4}

# %%
#replace whitespace with NaN and check for an decrease in blank_check and increase in null
#The increase seen with .isnull() is due to us replacing '' with 
Cambridge_df.replace(r'^\s*$', np.nan, regex=True, inplace=True)

# %%
#blank check after whitespace replacement
blank_check(Cambridge_df)
# Out:
# {'mwra_concentration': 0, 'mwra_7dayaverage': 0}

# %%
Cambridge_df.isnull().sum()
# Out:
# mwra_concentration    14
# mwra_7dayaverage       4
# dtype: int64

# %% [markdown]
# #### This passes the stench test now, and we can easily deal with NaNs.

# %%
#replace mwra_7dayaverage NaNs with .replace() and frontfill method
Cambridge_df.mwra_7dayaverage.replace(np.nan, method='ffill', inplace=True)

#replace mwra_concentration NaNs with the given mwra_7dayaverage using .fillna()
Cambridge_df.mwra_concentration.fillna(Cambridge_df.mwra_7dayaverage, inplace=True)

Cambridge_df.isnull().sum()
# Out:
# mwra_concentration    0
# mwra_7dayaverage      0
# dtype: int64

# %%
Cambridge_cleaned = Cambridge_df.copy()

# %% [markdown]
# ## Masschusetts Data

# %%
Mass_df.shape
# Out:
# (11296, 17)

# %%
Mass_df.columns
# Out:
# Index(['City/Town', 'County', 'Population', 'Total Case Counts',
#        'Two Week Case Counts', 'Average Daily Rate', 'Color',
#        'Change in Last Week', 'Total Tests', 'Total Tests Last Two Weeks',
#        'Total Positive Tests', 'Percent Positivity', 'Change Since Last Week',
#        'Testing Rate', 'Report Date', 'Start_Date', 'End_Date'],
#       dtype='object')

# %%
Mass_df.County.value_counts()
# Out:
# Worcester     1920
# Middlesex     1728
# Essex         1088
# Berkshire     1024
# Norfolk        896
# Plymouth       864
# Franklin       832
# Hampden        736
# Hampshire      640
# Bristol        640
# Barnstable     480
# Dukes          224
# Suffolk        128
# Statewide       32
# Unknown         32
# Nantucket       32
# Name: County, dtype: int64

# %%
num_nulls = Mass_df.isnull().sum()
print(blank_check(Mass_df), num_nulls)
# Out:
# {'City/Town': 0, 'County': 0, 'Population': 0, 'Total Case Counts': 0, 'Two Week Case Counts': 0, 'Average Daily Rate': 0, 'Color': 0, 'Change in Last Week': 0, 'Total Tests': 0, 'Total Tests Last Two Weeks': 0, 'Total Positive Tests': 0, 'Percent Positivity': 0, 'Change Since Last Week': 0, 'Testing Rate': 0, 'Report Date': 0, 'Start_Date': 0, 'End_Date': 0, 'per': 0} City/Town                        0
# County                           0
# Population                       0
# Total Case Counts                0
# Two Week Case Counts             0
# Average Daily Rate               0
# Color                         1801
# Change in Last Week              0
# Total Tests                      0
# Total Tests Last Two Weeks       1
# Total Positive Tests             1
# Percent Positivity               1
# Change Since Last Week           0
# Testing Rate                     4
# Report Date                      0
# Start_Date                       0
# End_Date                         0
# per                              0
# dtype: int64

# %% [markdown]
# #### I've decided to drop columns after I merge the Massachusetts and Biobot dfs.

# %% [markdown]
# ## Biobot Data

# %%
Biobot_df.isnull().sum()
# Out:
# sampling_week                               0
# normalized_concentration_rolling_average    0
# population                                  0
# region                                      0
# state                                       0
# county_fips_code                            0
# county_name                                 0
# dtype: int64

# %%
blank_check(Biobot_df)
# Out:
# {'sampling_week': 0,
#  'normalized_concentration_rolling_average': 0,
#  'population': 0,
#  'region': 0,
#  'state': 0,
#  'county_fips_code': 0,
#  'county_name': 0}

# %%
Biobot_df.shape
# Out:
# (1267, 7)

# %%
print(Biobot_df.state.value_counts(), Biobot_df.state.value_counts().sum())
# Out:
# MA    257
# PA    184
# CA    141
# IN     81
# TN     65
# FL     59
# NV     58
# KY     55
# CT     54
# OR     49
# VA     49
# CO     48
# NY     38
# DE     36
# IL     35
# MN     30
# NJ     28
# Name: state, dtype: int64 1267

# %% [markdown]
# Biobot performed the most WBE surveillance in Massachusetts. Affirms my choice to use their dataset.

# %%
#Let's slice for MA data only
Biobot_MA = pd.DataFrame(Biobot_df.loc[Biobot_df.state=='MA'])

# %%
Biobot_MA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 257 entries, 146 to 714
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   sampling_week                             257 non-null    object
#  1   normalized_concentration_rolling_average  257 non-null    float64
#  2   population                                257 non-null    object
#  3   region                                    257 non-null    object
#  4   state                                     257 non-null    object
#  5   county_fips_code                          257 non-null    int64
#  6   county_name                               257 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 16.1+ KB

# %% [markdown]
# ### Comparing Biobot's wastewater data to Cambridge

# %%
pd.DataFrame(Cambridge_df.loc['2020-Dec':'2021-Jan', ('mwra_concentration', 'mwra_7dayaverage')])
# Out:
#            mwra_concentration mwra_7dayaverage
# date
# 2020-12-01                862              576
# 2020-12-02                857              630
# 2020-12-03                888              685
# 2020-12-04               1384              779
# 2020-12-05                956              844
# ...                       ...              ...
# 2021-01-27                350              549
# 2021-01-28                421              523
# 2021-01-29                329              470
# 2021-01-30                490              434
# 2021-01-31                397              403
#
# [62 rows x 2 columns]

# %%
bio_middlesex = pd.DataFrame(Biobot_MA.loc[Biobot_MA.County == 'Middlesex'])
pd.DataFrame(bio_middlesex.loc['2020-Dec':'2021-Jan', 'normalized_concentration_rolling_average'])
# Out:
#                normalized_concentration_rolling_average
# sampling_week
# 2020-12-02                                   212.653435
# 2020-12-09                                   291.989119
# 2020-12-16                                   396.851090
# 2020-12-23                                   454.722050
# 2020-12-30                                   407.335752
# 2021-01-06                                   330.828325
# 2021-01-13                                   265.228983
# 2021-01-20                                   260.880836
# 2021-01-27                                   218.415714

# %% [markdown]
# The Cambrdge_df mwra (a measure of covid-19 rna concentration in wastewater) doesn't look like it matches Biobot's.
# Makes sense, as Biobot's is a normalized rolling average
# As Biobot has the larger dataset, I think I will use that over Cambridge_df.

# %% [markdown]
# ## Merging Mass_df and Biobot_MA DataFrames
#
# ### Set the indices for all df to a 'period' datetime range, with week starting on Monday

# %%
#setting the indices to all 3 dfs to be a datetime
cam_date = pd.to_datetime(Cambridge_df.date, infer_datetime_format=True)
Cambridge_df.set_index(cam_date, inplace=True)

mass_date = pd.to_datetime(Mass_df['Report Date'], infer_datetime_format=True)
Mass_df.set_index(mass_date, 
                  inplace=True)

biobot_date = pd.to_datetime(Biobot_MA['sampling_week'], infer_datetime_format=True)
Biobot_MA.set_index(biobot_date, 
                    inplace=True)

# %%
#Creating a period feature, using W-MON as the parameter
# I do this so I can easily merge these dfs on a standardized time, as the dates on the reports may not match other dfs
Cambridge_df['per'] = Cambridge_df.index.to_period('W-MON')
Mass_df['per'] = Mass_df.index.to_period('W-MON')
Biobot_MA['per'] = Biobot_MA.index.to_period('W-MON')

# %%
#This is so I can see what are the common periods between teh two dfs
common_periods = []
for x in Biobot_MA.per.values:
    if x in Mass_df.per.values and x not in common_periods:
        common_periods.append(x)

common_periods

# %% [markdown]
# ### Slicing by the common_periods shared throughout the dfs

# %%
#this is no longer needed now I know how to merge on multiple columns. Keeping for review
#Mass_sliced_by_common_periods = pd.DataFrame(Mass_df.loc[Mass_df['per'].isin(common_periods)])
#Biobot_MA_sliced_by_common_periods = pd.DataFrame(Biobot_MA.loc[Biobot_MA['per'].isin(common_periods)])

# %%
#These names are a mouthful, changing to shorter ones
df_b = pd.DataFrame(Biobot_MA)
df_m = pd.DataFrame(Mass_df)

#unifying the County features between the two df
df_b['County'] = df_b['county_name']

#dropping redundant or non-interested features from df_b
drop_list = ['region', 'state', 'county_fips_code', 'county_name']
df_b.drop(columns=drop_list, inplace=True)

#dropping redundant or non-interested features from df_m
kept_list = ['City/Town', 'County', 'Change Since Last Week', 'Percent Positivity', 'per', 'Report Date']
df_m.drop(columns=df_m.columns.difference(kept_list), inplace=True)

# %%
#As this is statewide data from MA Dept of Health, all the counties and their reports amount to a large number
num_reports = df_m.County.value_counts().sum()
num_counties = df_m.County.nunique()
print(num_reports, num_counties)
# Out:
# 11296 16

# %%
#However Biobot only conducted wastewater surveillance at a select number of counties
bio_num_reports = df_b.County.value_counts().sum()
bio_num_counties = df_b.County.nunique()
print(bio_num_reports, bio_num_counties)
# Out:
# 257 6

# %% [markdown]
# ### Merging

# %%
test_merge = df_b.merge(test_df, how='outer', on=['County', 'per'])

# %%
#doing an inner merge, and we can specify multiple columns on which it will merge
merged_df = df_b.merge(df_m, how='inner', on=['County', 'per'])

# %% [markdown]
# ### Reviewing and Wranging the merged_df

# %%
merged_df.head()
# Out:
#   sampling_week  normalized_concentration_rolling_average    population  \
# 0    2020-12-23                                420.042264  50000-100000
# 1    2020-12-23                                420.042264  50000-100000
# 2    2020-12-23                                420.042264  50000-100000
# 3    2020-12-23                                420.042264  50000-100000
# 4    2020-12-23                                420.042264  50000-100000
#
#                      per     County   City/Town Percent Positivity  \
# 0  2020-12-22/2020-12-28  Berkshire       Adams           0.028758
# 1  2020-12-22/2020-12-28  Berkshire      Alford                  0
# 2  2020-12-22/2020-12-28  Berkshire      Becket               0.04
# 3  2020-12-22/2020-12-28  Berkshire    Cheshire           0.024055
# 4  2020-12-22/2020-12-28  Berkshire  Clarksburg           0.010101
#
#   Change Since Last Week Report Date
# 0                  Lower  2020-12-24
# 1              No Change  2020-12-24
# 2                 Higher  2020-12-24
# 3                 Higher  2020-12-24
# 4                  Lower  2020-12-24

# %%
#expect the number of counties to match bio_num_counties
merged_num_counties = merged_df.County.nunique()
print(bio_num_counties, merged_num_counties)
# Out:
# 6 6

# %%
merged_df.shape
# Out:
# (3162, 9)

# %%
merged_df.duplicated().any()
# Out:
# False

# %%
merged_df.isnull().sum()
# Out:
# sampling_week                               0
# normalized_concentration_rolling_average    0
# population                                  0
# per                                         0
# County                                      0
# City/Town                                   0
# Percent Positivity                          0
# Change Since Last Week                      0
# Report Date                                 0
# dtype: int64

# %%
blank_check(merged_df)
# Out:
# {'sampling_week': 0,
#  'normalized_concentration_rolling_average': 0,
#  'population': 0,
#  'per': 0,
#  'County': 0,
#  'City/Town': 0,
#  'Percent Positivity': 0,
#  'Change Since Last Week': 0,
#  'Report Date': 0}

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3162 entries, 0 to 3161
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   sampling_week                             3162 non-null   object
#  1   normalized_concentration_rolling_average  3162 non-null   float64
#  2   population                                3162 non-null   object
#  3   per                                       3162 non-null   period[W-MON]
#  4   County                                    3162 non-null   object
#  5   City/Town                                 3162 non-null   object
#  6   Percent Positivity                        3162 non-null   object
#  7   Change Since Last Week                    3162 non-null   object
#  8   Report Date                               3162 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(6), period[W-MON](1)
# memory usage: 247.0+ KB

# %% [markdown]
# ### In what I would expect to be my categorical features, I am checking and counting unique values

# %%
cat_list = ['population', 'County', 'City/Town', 'Change Since Last Week']
[merged_df[x].value_counts() for x in cat_list]
# Out:
# [100000-200000      1296
#  20000-50000         968
#  50000-100000        640
#  10000-20000         158
#  2000000-5000000     100
#  Name: population, dtype: int64,
#  Middlesex    1350
#  Essex         748
#  Berkshire     640
#  Hampshire     300
#  Suffolk       100
#  Nantucket      24
#  Name: County, dtype: int64,
#  Watertown      25
#  Wakefield      25
#  Everett        25
#  Woburn         25
#  Reading        25
#                 ..
#  Pelham         15
#  Southampton    15
#  Worthington    15
#  Cummington     15
#  Hatfield       15
#  Name: City/Town, Length: 145, dtype: int64,
#  Lower        1402
#  Higher        953
#  No Change     587
#  Lower         220
#  Name: Change Since Last Week, dtype: int64]

# %%
#in 'Change Since Last Week', Lower shows up twice in the value_counts()
merged_df['Change Since Last Week'].value_counts()
# Out:
# Lower        1402
# Higher        953
# No Change     587
# Lower         220
# Name: Change Since Last Week, dtype: int64

# %%
#I suspect there is a whitespace after the r in one of them
(merged_df['Change Since Last Week'].values == 'Lower ').sum()
# Out:
# 220

# %%
#confirmed 220 with whitespace, replacing.
merged_df['Change Since Last Week'].replace('Lower ', 'Lower', inplace=True)

# %%
merged_df['Change Since Last Week'].value_counts()
# Out:
# Lower        1622
# Higher        953
# No Change     587
# Name: Change Since Last Week, dtype: int64

# %%
(merged_df['Change Since Last Week'].values == 'Lower ').sum()
# Out:
# 0

# %%
cleaned_df = merged_df.copy()

# %%
blank_check(cleaned_df), cleaned_df.isnull().sum()
# Out:
# ({'sampling_week': 0,
#   'normalized_concentration_rolling_average': 0,
#   'population': 0,
#   'per': 0,
#   'County': 0,
#   'City/Town': 0,
#   'Percent Positivity': 0,
#   'Change Since Last Week': 0,
#   'Report Date': 0},
#  sampling_week                               0
#  normalized_concentration_rolling_average    0
#  population                                  0
#  per                                         0
#  County                                      0
#  City/Town                                   0
#  Percent Positivity                          0
#  Change Since Last Week                      0
#  Report Date                                 0
#  dtype: int64)

# %% [markdown]
# ## Note about this merged dataframe:
# 1. I think this is considered an inner merge. Based on the 'per' and 'County' columns.
# 2. Inner Join imputed the many features from the Mass_df to Biobot_MA.
# 3. Ready for EDA 7.26.21 NS

# %%
#Some summary statistics
cleaned_df.describe(), cleaned_df.shape
# Out:
# (       normalized_concentration_rolling_average
#  count                               3162.000000
#  mean                                 195.761188
#  std                                  220.679590
#  min                                    0.000000
#  25%                                   50.628972
#  50%                                  108.200214
#  75%                                  265.228983
#  max                                 1548.370985,
#  (3162, 9))

# %% [markdown]
# ### At every Unit submission, I will create a new pickle file.

# %%
#cleaned_df.to_pickle('Unit11EDA.pkl') #Created 7.27.21 NS and commented out for Github submission

# %% [markdown]
# # Exploratory Data Analysis (Unit 11.5)

# %% [markdown]
# ### Goal from the rubric:
# 1. Investigate every feature using histograms, bi-plots, or other visual and numeric means
# 2. Pearson correlation coefficients and other statistical methods were used to ID statistical relationship strengths

# %%
with open('Unit11EDA.pkl', 'rb') as f:
    df = pickle.load(f)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3162 entries, 0 to 3161
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   sampling_week                             3162 non-null   object
#  1   normalized_concentration_rolling_average  3162 non-null   float64
#  2   population                                3162 non-null   object
#  3   per                                       3162 non-null   period[W-MON]
#  4   County                                    3162 non-null   object
#  5   City/Town                                 3162 non-null   object
#  6   Percent Positivity                        3162 non-null   object
#  7   Change Since Last Week                    3162 non-null   object
#  8   Report Date                               3162 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(6), period[W-MON](1)
# memory usage: 247.0+ KB

# %% [markdown]
# ### The types of the features may be problematic when trying to run statistical analysis. Let's see what types they should be, and then do the proper vectorized conversion.

# %%
#As always, I use copy when doing any testing
test = df.copy()

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3162 entries, 0 to 3161
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   sampling_week                             3162 non-null   object
#  1   normalized_concentration_rolling_average  3162 non-null   float64
#  2   population                                3162 non-null   object
#  3   per                                       3162 non-null   period[W-MON]
#  4   County                                    3162 non-null   object
#  5   City/Town                                 3162 non-null   object
#  6   Percent Positivity                        3162 non-null   object
#  7   Change Since Last Week                    3162 non-null   object
#  8   Report Date                               3162 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(6), period[W-MON](1)
# memory usage: 247.0+ KB

# %%
test.head()
# Out:
#   sampling_week  normalized_concentration_rolling_average    population  \
# 0    2020-12-23                                420.042264  50000-100000
# 1    2020-12-23                                420.042264  50000-100000
# 2    2020-12-23                                420.042264  50000-100000
# 3    2020-12-23                                420.042264  50000-100000
# 4    2020-12-23                                420.042264  50000-100000
#
#                      per     County   City/Town Percent Positivity  \
# 0  2020-12-22/2020-12-28  Berkshire       Adams           0.028758
# 1  2020-12-22/2020-12-28  Berkshire      Alford                  0
# 2  2020-12-22/2020-12-28  Berkshire      Becket               0.04
# 3  2020-12-22/2020-12-28  Berkshire    Cheshire           0.024055
# 4  2020-12-22/2020-12-28  Berkshire  Clarksburg           0.010101
#
#   Change Since Last Week Report Date
# 0                  Lower  2020-12-24
# 1              No Change  2020-12-24
# 2                 Higher  2020-12-24
# 3                 Higher  2020-12-24
# 4                  Lower  2020-12-24

# %%
test.tail()
# Out:
#      sampling_week  normalized_concentration_rolling_average       population  \
# 3157    2021-06-02                                 28.980287  2000000-5000000
# 3158    2021-06-09                                 26.426384  2000000-5000000
# 3159    2021-06-09                                 26.426384  2000000-5000000
# 3160    2021-06-09                                 26.426384  2000000-5000000
# 3161    2021-06-09                                 26.426384  2000000-5000000
#
#                         per   County City/Town Percent Positivity  \
# 3157  2021-06-01/2021-06-07  Suffolk  Winthrop           0.007618
# 3158  2021-06-08/2021-06-14  Suffolk    Boston           0.004727
# 3159  2021-06-08/2021-06-14  Suffolk   Chelsea           0.008971
# 3160  2021-06-08/2021-06-14  Suffolk    Revere           0.009459
# 3161  2021-06-08/2021-06-14  Suffolk  Winthrop            0.00624
#
#      Change Since Last Week Report Date
# 3157                  Lower  2021-06-03
# 3158              No Change  2021-06-10
# 3159                  Lower  2021-06-10
# 3160                  Lower  2021-06-10
# 3161                  Lower  2021-06-10

# %%
#I really hate typing out the 'normalized_concentration_rolling_average'
test['avg_concentration'] = test['normalized_concentration_rolling_average']
test.drop(columns='normalized_concentration_rolling_average', inplace=True)

df['avg_concentration'] = df['normalized_concentration_rolling_average']
df.drop(columns='normalized_concentration_rolling_average', inplace=True)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3162 entries, 0 to 3161
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   sampling_week           3162 non-null   object
#  1   population              3162 non-null   object
#  2   per                     3162 non-null   period[W-MON]
#  3   County                  3162 non-null   object
#  4   City/Town               3162 non-null   object
#  5   Percent Positivity      3162 non-null   object
#  6   Change Since Last Week  3162 non-null   object
#  7   Report Date             3162 non-null   datetime64[ns]
#  8   avg_concentration       3162 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6), period[W-MON](1)
# memory usage: 247.0+ KB

# %% [markdown]
# ### Here's how I think they should be converted
# 1. Category = ['population', 'County', 'City/Town', 'Change Since Last Week']
# 2. Float64 = ['avg_concentration', 'Percent Positivity']
# 3. Datetime = ['sampling_week', 'Report Date']
#
# Will create a unit test first.

# %%
category_list = ['population', 'County', 'City/Town', 'Change Since Last Week']

float64_list = ['avg_concentration', 'Percent Positivity']

datetime_list = ['sampling_week']

conversion_list = [datetime_list, category_list, float64_list]

# %%
#Unit testing my conversion loop logic
for list in conversion_list:
    print(list)
    for col in list:
        if col in datetime_list:
            print('Will convert these to datetime: ', col)
        if col in category_list:
            print('Will convert these to category: ',col)
        if col in float64_list:
            print('Will convert these to float64: ', col)
# Out:
# ['sampling_week']
# Will convert these to datetime:  sampling_week
# ['population', 'County', 'City/Town', 'Change Since Last Week']
# Will convert these to category:  population
# Will convert these to category:  County
# Will convert these to category:  City/Town
# Will convert these to category:  Change Since Last Week
# ['avg_concentration', 'Percent Positivity']
# Will convert these to float64:  avg_concentration
# Will convert these to float64:  Percent Positivity

# %%
for list in conversion_list:
    for col in list:
        if col in datetime_list:
            test[col] = pd.to_datetime(test[col], infer_datetime_format=True)
            #print('These should be converted to int64: ', col)
        if col in category_list:
            test[col] = test[col].astype('category')
            #print('These should be converted to categories: ', col)
        if col in float64_list:
            test[col] = test[col].astype('float64')
            #print('These should be converted to float64: ', col)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3162 entries, 0 to 3161
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   sampling_week           3162 non-null   datetime64[ns]
#  1   population              3162 non-null   category
#  2   per                     3162 non-null   period[W-MON]
#  3   County                  3162 non-null   category
#  4   City/Town               3162 non-null   category
#  5   Percent Positivity      3162 non-null   float64
#  6   Change Since Last Week  3162 non-null   category
#  7   Report Date             3162 non-null   datetime64[ns]
#  8   avg_concentration       3162 non-null   float64
# dtypes: category(4), datetime64[ns](2), float64(2), period[W-MON](1)
# memory usage: 169.4 KB

# %% [markdown]
# ### Conversion unit test passes, convert all features in df

# %%
def conversion(df, conversion_list):
    '''Method to convert my features into their appropriate datatypes'''
    for list in conversion_list:
        for col in list:
            if col in datetime_list:
                df[col] = pd.to_datetime(test[col], infer_datetime_format=True)
            if col in category_list:
                df[col] = df[col].astype('category')
            if col in float64_list:
                df[col] = df[col].astype('float64')

# %%
#Pre-conversion
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3162 entries, 0 to 3161
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   sampling_week           3162 non-null   object
#  1   population              3162 non-null   object
#  2   per                     3162 non-null   period[W-MON]
#  3   County                  3162 non-null   object
#  4   City/Town               3162 non-null   object
#  5   Percent Positivity      3162 non-null   object
#  6   Change Since Last Week  3162 non-null   object
#  7   Report Date             3162 non-null   datetime64[ns]
#  8   avg_concentration       3162 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6), period[W-MON](1)
# memory usage: 247.0+ KB

# %%
conversion(df, conversion_list)

# %%
#Post-conversion
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3162 entries, 0 to 3161
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   sampling_week           3162 non-null   datetime64[ns]
#  1   population              3162 non-null   category
#  2   per                     3162 non-null   period[W-MON]
#  3   County                  3162 non-null   category
#  4   City/Town               3162 non-null   category
#  5   Percent Positivity      3162 non-null   float64
#  6   Change Since Last Week  3162 non-null   category
#  7   Report Date             3162 non-null   datetime64[ns]
#  8   avg_concentration       3162 non-null   float64
# dtypes: category(4), datetime64[ns](2), float64(2), period[W-MON](1)
# memory usage: 169.4 KB

# %% [markdown]
# ### Dtypes have been converted to the intended type, let's do some Exploratory Data Analysis!

# %% [markdown]
# It's always a good idea to get a sense of the data's distribution.
# Here's what I'm interested in:
# 1. avg_concentration - float64
# 2. Change Since Last Week - categorical
# 3. Percent Positivity - float64

# %%
#This is NOT a normal distribution. Uh-oh...
sns.distplot(df.avg_concentration)
plt.xlabel('Average Concentration of Covid-19 mRNA found in wastewater')
plt.title('Avg_concentration Distribution')
# Out:
# C:\Users\Aim\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Avg_concentration Distribution')

# %%
#setting a threshold of less than 700 to see if I can yield a more normal dist
data = [x for x in df.avg_concentration if x <700]
sns.displot(data)

# %%
#Move to pre-processing
#transforming avg_concentration to be more Gaussian by using Box-Cox
df2 = pd.DataFrame(df.loc[~(df.avg_concentration == 0)]) #filter out for zeroes
data = stats.boxcox(df2.avg_concentration)
df2['boxcox'] = data[0]

#plotting boxcox transformation of avg_concentration
sns.displot(data=df2, x=df2.boxcox)
plt.xlabel('Count')
plt.ylabel('avg_concentration')
plt.title('Box-Cox Power Transformed avg_concentration')
# Out:
# Text(0.5, 1.0, 'Box-Cox Power Transformed avg_concentration')

# %%
#BoxCox could not process non-positivie (including zeroes).
#Yeo-Johnson may be a better transformation as there are no negative numbers
data = stats.yeojohnson(df.avg_concentration) #note this wasn't sliced for non-zero
df3 = df.copy()
df3['yeo'] = data[0]
sns.displot(data=df3, x=df3.yeo)
plt.ylabel('avg_concentration')
plt.xlabel('Count')
plt.title('Yeo-Johnson Power Transformed of avg_concentration')
# Out:
# Text(0.5, 1.0, 'Yeo-Johnson Power Transformed of avg_concentration')

# %%
df2.yeo.max()
# Out:
# 21.118253208015627

# %%
#move to preprocessing
#checking whether the corr coefficients of transformed do better
df2.drop(columns=['population', 'County', 'City/Town'], inplace=True)
test = pd.get_dummies(df2)
test.corr()
# Out:
#                                   Percent Positivity  avg_concentration  \
# Percent Positivity                          1.000000           0.446232
# avg_concentration                           0.446232           1.000000
# boxcox                                      0.455646           0.837264
# yeo                                         0.468842           0.876306
# Change Since Last Week_Higher               0.240200           0.197618
# Change Since Last Week_Lower               -0.027478          -0.126335
# Change Since Last Week_No Change           -0.248307          -0.070873
#
#                                     boxcox       yeo  \
# Percent Positivity                0.455646  0.468842
# avg_concentration                 0.837264  0.876306
# boxcox                            1.000000  0.991019
# yeo                               0.991019  1.000000
# Change Since Last Week_Higher     0.195732  0.200758
# Change Since Last Week_Lower     -0.104616 -0.108447
# Change Since Last Week_No Change -0.096581 -0.097588
#
#                                   Change Since Last Week_Higher  \
# Percent Positivity                                     0.240200
# avg_concentration                                      0.197618
# boxcox                                                 0.195732
# yeo                                                    0.200758
# Change Since Last Week_Higher                          1.000000
# Change Since Last Week_Lower                          -0.674455
# Change Since Last Week_No Change                      -0.313406
#
#                                   Change Since Last Week_Lower  \
# Percent Positivity                                   -0.027478
# avg_concentration                                    -0.126335
# boxcox                                               -0.104616
# yeo                                                  -0.108447
# Change Since Last Week_Higher                        -0.674455
# Change Since Last Week_Lower                          1.000000
# Change Since Last Week_No Change                     -0.489741
#
#                                   Change Since Last Week_No Change
# Percent Positivity                                       -0.248307
# avg_concentration                                        -0.070873
# boxcox                                                   -0.096581
# yeo                                                      -0.097588
# Change Since Last Week_Higher                            -0.313406
# Change Since Last Week_Lower                             -0.489741
# Change Since Last Week_No Change                          1.000000

# %%
#The yeo-johnson transformed avg_concentration yields a better corr coefficient than boxcox
test.drop('boxcox', axis=1, inplace=True)

# %%
sns.displot(data=df, x='Percent Positivity')
plt.xlabel('Percent Positivity')
plt.title('Percent Positivity Distribution')
# Out:
# Text(0.5, 1.0, 'Percent Positivity Distribution')

# %%
#Percent positivity distribution is not normal. May need to pre-process.
#possible transform ideas:
#1. Box Cox
#2. Yeo-Johnson

#There is a min val of 0, Box-Cox may not work on it
df['Percent Positivity'].describe()
# Out:
# count    3162.000000
# mean        0.030726
# std         0.031663
# min         0.000000
# 25%         0.010101
# 50%         0.023529
# 75%         0.041790
# max         0.555556
# Name: Percent Positivity, dtype: float64

# %%
#move to pre-processing
data = stats.yeojohnson(df['Percent Positivity'])
df4 = df3.copy()
df4['PP-Yeo'] = data[0]
sns.displot(data=df4, x='PP-Yeo')
plt.xlabel('Yeo-Johnson Percent Positivity')
plt.title('Yeo-Johnson Transformation of Percent Positivity')
# Out:
# Text(0.5, 1.0, 'Yeo-Johnson Transformation of Percent Positivity')

# %%
df4[['yeo', 'PP-Yeo','avg_concentration']].corr()
# Out:
#                         yeo    PP-Yeo  avg_concentration
# yeo                1.000000  0.531349           0.876238
# PP-Yeo             0.531349  1.000000           0.466906
# avg_concentration  0.876238  0.466906           1.000000

# %%
#Using autocorrelation (because this is a time series!) to see if yeo-transformed avg_concentration 
#can forecast.
#trying to see a pattern to see least amount of days needed to forecast
#iterating through a week with 1 through 6 lagged days to forecast
# %matplotlib inline

#unpacking ax into an [3, 2] array to be called later in .plot_acf() 
fig, [[ax1, ax2], [ax3, ax4], [ax5, ax6]] = plt.subplots(nrows=3, ncols=2, 
                                                         sharex=True, sharey=True,
                                                         figsize=(21,9))
axList = [ax1, ax2, ax3, ax4, ax5, ax6]

for x in range(1,7):
    ac=sm.tsa.acf(df4.yeo, nlags=x, fft=True)
    y = x-1
    tsaplots.plot_acf(ac, ax=axList[y])
plt.tight_layout()
plt.show()

#maybe 6 days needed? Will need a windowing function. Perhaps a weighted one.

# %%
#Using autocorrelation (because this is a time series!) to see if yeo-transformed Percentage Positivity can forecast
ac = sm.tsa.acf(df4['PP-Yeo'], nlags=21, fft=False)
fig = tsaplots.plot_acf(ac)
plt.show()

# %%
dummies = pd.get_dummies(df['Change Since Last Week'], prefix='Since Last Week')
#period = pd.Series(df.per)
#date = pd.Series(df['Report Date'])
#dummy_df = pd.DataFrame([date, period, dummies])
dummy_df = pd.DataFrame(dummies.merge(df['Report Date'], left_index=True, right_index=True))

# %%
ac = sm.tsa.acf(dummy_df['Since Last Week_Higher'], nlags=14, fft=False)
fig = tsaplots.plot_acf(ac)
plt.show()

# %%
sns.barplot(data = df, x='Change Since Last Week', y=df.avg_concentration)
# Out:
# <AxesSubplot:xlabel='Change Since Last Week', ylabel='avg_concentration'>

# %% [markdown]
# ### Distribution takeaways:
# 1. Concentration and Positivity are not uniform, shows skewedness
# 2. In Change Since the majority of the datapoints are 'lower'
# 3. in Change Since, the 'Higher' category seems to have the higher avg_concentration values
#
# Let's explore any correlation gained from this insight.

# %%
#I need to drop some features or my system won't be able to process the dummy variables for the .corr()
test = pd.DataFrame(df.drop(columns=['City/Town', 'County', 'population']))
#test = df.copy()

# %%
#I know dummies should be reserved to pre-processing but I couldn't help myself
test = pd.get_dummies(test)

# %%
plt.figure(figsize = (21,9))
sns.heatmap(test.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The heatmap is a great visual tool, as it looks at all the non-categorical data, and with the right parameters even annotates their Pearson r value.

# %%
#If I didn't want that great visualization...
test.corr()
# Out:
#                                   Percent Positivity  avg_concentration  \
# Percent Positivity                          1.000000           0.446349
# avg_concentration                           0.446349           1.000000
# Change Since Last Week_Higher               0.240319           0.197764
# Change Since Last Week_Lower               -0.027224          -0.126010
# Change Since Last Week_No Change           -0.248616          -0.071403
#
#                                   Change Since Last Week_Higher  \
# Percent Positivity                                     0.240319
# avg_concentration                                      0.197764
# Change Since Last Week_Higher                          1.000000
# Change Since Last Week_Lower                          -0.674083
# Change Since Last Week_No Change                      -0.313602
#
#                                   Change Since Last Week_Lower  \
# Percent Positivity                                   -0.027224
# avg_concentration                                    -0.126010
# Change Since Last Week_Higher                        -0.674083
# Change Since Last Week_Lower                          1.000000
# Change Since Last Week_No Change                     -0.489999
#
#                                   Change Since Last Week_No Change
# Percent Positivity                                       -0.248616
# avg_concentration                                        -0.071403
# Change Since Last Week_Higher                            -0.313602
# Change Since Last Week_Lower                             -0.489999
# Change Since Last Week_No Change                          1.000000

# %% [markdown]
# There is a mild correlation (0.446349) between avg_concentration and Percent Positivity.
#
# There is a weak correlation (0.197764) between avg_concentration and a Higher Change Since Last Week

# %% [markdown]
# ### Using graphs can be a powerful tool to gain insight into the relationship between features.

# %%
plt.figure(figsize=(16,9))
sns.lineplot(y='Percent Positivity', x=df['Report Date'], data=df, hue='County', ax=None, ci=None)
plt.title('Percent Positivity of the Surveiled Counties')
# Out:
# Text(0.5, 1.0, 'Percent Positivity of the Surveiled Counties')

# %% [markdown]
# Some subject matter understanding of the vaccination rollouts will explain the downward trend in early 2021, and the vaccine hesitancy and resistance coupled with variants being introduced could explain the upward trends seen after March 2021.

# %%
plt.figure(figsize=(16,9))
sns.lineplot(y='avg_concentration', x=df['Report Date'], data=df)
plt.title('Average Concentration of Covid-19 mRNA found in Wastewater')
# Out:
# Text(0.5, 1.0, 'Average Concentration of Covid-19 mRNA found in Wastewater')

# %%
plt.figure(figsize=(16,9))
sns.lineplot(data=df, x=df['Report Date'], y='avg_concentration', hue='County')
# Out:
# <AxesSubplot:xlabel='Report Date', ylabel='avg_concentration'>

# %%
plt.figure(figsize=(16,9))
sns.scatterplot(data = df, x=df['Percent Positivity'], y=df.avg_concentration)
sns.regplot(data = df, x=df['Percent Positivity'], y=df.avg_concentration)
plt.title('Percent Positivity and MWRA Concentration Scatter Plot')
df.avg_concentration.corr(df['Percent Positivity']).round(5)
# Out:
# 0.44635

# %%
df.loc[df['County']=='Nantucket', ['Change Since Last Week', 'Percent Positivity', 'avg_concentration']]
# Out:
#      Change Since Last Week  Percent Positivity  avg_concentration
# 3038                  Lower            0.107834        1103.682440
# 3039                  Lower            0.074365        1388.740515
# 3040                 Higher            0.087600        1548.370985
# 3041                 Higher            0.116615        1393.287782
# 3042                  Lower            0.093977         776.575043
# 3043                  Lower            0.066388         320.149919
# 3044                  Lower            0.059866         142.016800
# 3045                  Lower            0.044529         146.132957
# 3046                  Lower            0.038970         185.513472
# 3047                  Lower            0.027347         253.187697
# 3048                  Lower            0.014031         292.375740
# 3049                 Higher            0.018235         429.157432
# 3050                 Higher            0.039731         499.072282
# 3051                 Higher            0.049285         629.986470
# 3052                 Higher            0.061350         696.031396
# 3053                 Higher            0.084926         626.884337
# 3054                  Lower            0.066874         504.438574
# 3055                  Lower            0.061224         261.649535
# 3056                  Lower            0.053734         139.760826
# 3057                  Lower            0.041667          69.157821
# 3058                  Lower            0.030435          29.608822
# 3059                  Lower            0.016393          21.132568
# 3060                  Lower            0.006726           0.971260
# 3061              No Change            0.006637           0.000000

# %%
test = df.copy()

# %%
test['concentration_pct_change'] = test.avg_concentration.pct_change(periods=1)*100

# %%
test.loc[test['County']=='Nantucket', ['Report Date', 
                                      'Change Since Last Week', 
                                      'Percent Positivity', 
                                      'avg_concentration', 
                                      'concentration_pct_change']]
# Out:
#      Report Date Change Since Last Week  Percent Positivity  \
# 3038  2020-12-24                  Lower            0.107834
# 3039  2020-12-31                  Lower            0.074365
# 3040  2021-01-07                 Higher            0.087600
# 3041  2021-01-14                 Higher            0.116615
# 3042  2021-01-21                  Lower            0.093977
# 3043  2021-01-28                  Lower            0.066388
# 3044  2021-02-04                  Lower            0.059866
# 3045  2021-02-11                  Lower            0.044529
# 3046  2021-02-18                  Lower            0.038970
# 3047  2021-02-25                  Lower            0.027347
# 3048  2021-03-04                  Lower            0.014031
# 3049  2021-03-11                 Higher            0.018235
# 3050  2021-03-18                 Higher            0.039731
# 3051  2021-03-25                 Higher            0.049285
# 3052  2021-04-01                 Higher            0.061350
# 3053  2021-04-08                 Higher            0.084926
# 3054  2021-04-22                  Lower            0.066874
# 3055  2021-04-29                  Lower            0.061224
# 3056  2021-05-06                  Lower            0.053734
# 3057  2021-05-13                  Lower            0.041667
# 3058  2021-05-20                  Lower            0.030435
# 3059  2021-05-27                  Lower            0.016393
# 3060  2021-06-03                  Lower            0.006726
# 3061  2021-06-10              No Change            0.006637
#
#       avg_concentration  concentration_pct_change
# 3038        1103.682440             270864.592701
# 3039        1388.740515                 25.827907
# 3040        1548.370985                 11.494622
# 3041        1393.287782                -10.015894
# 3042         776.575043                -44.263127
# 3043         320.149919                -58.774117
# 3044         142.016800                -55.640532
# 3045         146.132957                  2.898359
# 3046         185.513472                 26.948414
# 3047         253.187697                 36.479413
# 3048         292.375740                 15.477863
# 3049         429.157432                 46.782846
# 3050         499.072282                 16.291190
# 3051         629.986470                 26.231508
# 3052         696.031396                 10.483547
# 3053         626.884337                 -9.934474
# 3054         504.438574                -19.532433
# 3055         261.649535                -48.130546
# 3056         139.760826                -46.584722
# 3057          69.157821                -50.517020
# 3058          29.608822                -57.186589
# 3059          21.132568                -28.627463
# 3060           0.971260                -95.403964
# 3061           0.000000               -100.000000

# %% [markdown]
# ### I had a hunch. Could I see more patterns in the data if...
# 1. I grouped it by county/city
# 2. Look at it as a time series

# %%
#Grouping it by county
hunch = pd.DataFrame(test.loc[test['County']=='Nantucket', ['Report Date', 
                                      'Change Since Last Week', 
                                      'Percent Positivity', 
                                      'avg_concentration', 
                                      'concentration_pct_change']])

# %%
slice = ['County', 'City/Town', 'population',
         'Report Date', 'Change Since Last Week', 
         'Percent Positivity', 'avg_concentration', 
         'concentration_pct_change']
hunch = pd.DataFrame(test[slice])

# %%
hunch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3162 entries, 0 to 3161
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   County                    3162 non-null   category
#  1   City/Town                 3162 non-null   category
#  2   population                3162 non-null   category
#  3   Report Date               3162 non-null   datetime64[ns]
#  4   Change Since Last Week    3162 non-null   category
#  5   Percent Positivity        3162 non-null   float64
#  6   avg_concentration         3162 non-null   float64
#  7   concentration_pct_change  3161 non-null   float64
# dtypes: category(4), datetime64[ns](1), float64(3)
# memory usage: 273.7 KB

# %%
hunch.set_index('Report Date', drop=True, inplace=True)
hunch.sort_index()

#hunch = pd.get_dummies(hunch)
#hunch.corr()
# Out:
#                 County   City/Town       population Change Since Last Week  \
# Report Date
# 2020-12-24   Berkshire       Adams     50000-100000                  Lower
# 2020-12-24   Middlesex     Shirley    100000-200000                  Lower
# 2020-12-24   Middlesex    Sherborn    100000-200000              No Change
# 2020-12-24   Middlesex     Reading    100000-200000                 Higher
# 2020-12-24   Middlesex   Pepperell    100000-200000                 Higher
# ...                ...         ...              ...                    ...
# 2021-06-10       Essex      Wenham      20000-50000              No Change
# 2021-06-10       Essex   Topsfield      20000-50000                  Lower
# 2021-06-10       Essex  Swampscott      20000-50000                  Lower
# 2021-06-10       Essex   Salisbury      20000-50000                  Lower
# 2021-06-10     Suffolk    Winthrop  2000000-5000000                  Lower
#
#              Percent Positivity  avg_concentration  concentration_pct_change
# Report Date
# 2020-12-24             0.028758       4.200423e+02                       NaN
# 2020-12-24             0.106326       4.547221e+02                       0.0
# 2020-12-24             0.046422       4.547221e+02                       0.0
# 2020-12-24             0.056667       4.547221e+02                       0.0
# 2020-12-24             0.075949       4.547221e+02                       0.0
# ...                         ...                ...                       ...
# 2021-06-10             0.000000       9.947598e-14                       0.0
# 2021-06-10             0.002755       9.947598e-14                       0.0
# 2021-06-10             0.001242       9.947598e-14                       0.0
# 2021-06-10             0.017007       9.947598e-14                       0.0
# 2021-06-10             0.006240       2.642638e+01                       0.0
#
# [3162 rows x 7 columns]

# %%
#how many are null values
print('Np.nan\n', hunch.loc[hunch.values== np.nan].sum())


#how many have inf values
print('\nNp.inf\n', hunch.loc[hunch.values== np.inf].sum())
# Out:
# Np.nan
#  Percent Positivity          0.0
# avg_concentration           0.0
# concentration_pct_change    0.0
# dtype: float64
#
# Np.inf
#  Percent Positivity            0.034814
# avg_concentration           888.086036
# concentration_pct_change           inf
# dtype: float64

# %% [markdown]
# #### Some observation has a negative infinity in their features.
# Locate.

# %%
#above we see 'concentration_pct_change' has np.inf in them

#slicing all obs where 'concentration_pct_change' equals pos and neg inf
pos_inf = hunch['concentration_pct_change'] == np.inf
neg_inf = hunch['concentration_pct_change'] == -np.inf

#bitwise 'OR' slice 
hunch.loc[(pos_inf ^ neg_inf)]

#too long, look above for shorter code
#hunch.loc[((hunch['concentration_pct_change'] == np.inf) ^ (hunch['concentration_pct_change'] == -np.inf))]
# Out:
# Empty DataFrame
# Columns: [County, City/Town, population, Change Since Last Week, Percent Positivity, avg_concentration, concentration_pct_change]
# Index: []

# %% [markdown]
# Replace np.inf (both sides of infinity)

# %%
hunch.replace([np.inf, -np.inf], np.nan, inplace=True)
# Out:
# (3162, 7)

# %%
hunch.loc[((hunch['concentration_pct_change'] == np.inf) ^ (hunch['concentration_pct_change'] == -np.inf))]
# Out:
# Empty DataFrame
# Columns: [County, City/Town, population, Change Since Last Week, Percent Positivity, avg_concentration, concentration_pct_change]
# Index: []

# %%
#how many are null values
print('Np.nan\n', hunch.loc[hunch.values== np.nan].sum())


#how many have inf values
print('\nNp.inf\n', hunch.loc[hunch.values== np.inf].sum())
# Out:
# Np.nan
#  Percent Positivity          0.0
# avg_concentration           0.0
# concentration_pct_change    0.0
# dtype: float64
#
# Np.inf
#  Percent Positivity          0.0
# avg_concentration           0.0
# concentration_pct_change    0.0
# dtype: float64

# %%
hunch.dropna(inplace=True)
hunch.shape
# Out:
# (3160, 7)

# %%
hunch.concentration_pct_change.max()
# Out:
# 4.901396025991323e+17

# %%
hunch.reset_index(inplace=True)

# %%
for county in hunch.County: print(county)
# Out:
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Berkshire
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Essex
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Hampshire
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Middlesex
# Nantucket
# Nantucket
# Nantucket
# Nantucket
# Nantucket
# Nantucket
# Nantucket
# Nantucket
# Nantucket
# Nantucket
# Nantucket
# Nantucket
# Nantucket
# Nantucket
# Nantucket
# Nantucket
# Nantucket
# Nantucket
# Nantucket
# Nantucket
# Nantucket
# Nantucket
# Nantucket
# Nantucket
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk
# Suffolk

# %%
c_list = []
for county in hunch.County:
    if county not in c_list: c_list.append(county)

# %%
c_list
# Out:
# ['Berkshire', 'Essex', 'Hampshire', 'Middlesex', 'Nantucket', 'Suffolk']

# %%
test_dict = dict(zip([county for county in c_list], [hunch[hunch['County']==county] for county in c_list]))

# %%
for county, dataframe in test_dict.items():
    a = set()
    b = pd.dataframe
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2976-277de3e80a90> in <module>
#       1 for county, dataframe in test_dict.items():
#       2     a = set()
# ----> 3     b = pd.dataframe(dataframe['City/Town'])
#       4     a.add(b)
#       5     print(a)
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'dataframe'

# %%
a = set([0,1,2,3,4,4,5,6])
a
# Out:
# {0, 1, 2, 3, 4, 5, 6}

# %%
a.add(7)
a
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7}

# %%
a.add(3)
a
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7}

# %%
set([county for county in hunch.County])
# Out:
# {'Berkshire', 'Essex', 'Hampshire', 'Middlesex', 'Nantucket', 'Suffolk'}

# %%
plt.figure()
for counter, dataframe in enumerate([hunch[hunch['County']==county] for county in c_list]):
    #print('City/Town' in dataframe.columns)
    print()
    sns.lineplot(data=dataframe, x='Report Date', y='avg_concentration')

plt.show()

# %%
dict(zip([county for county in c_list], [hunch[county] for county in c_list]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Berkshire'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2928-7f148910cabc> in <module>
# ----> 1 dict(zip([county for county in c_list], [hunch[county] for county in c_list]))
#
# <ipython-input-2928-7f148910cabc> in <listcomp>(.0)
# ----> 1 dict(zip([county for county in c_list], [hunch[county] for county in c_list]))
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Berkshire'

# %%
hunch.loc[hunch['County']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2916-3abc935c840a> in <module>
# ----> 1 hunch.loc[hunch['County']]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1111                     raise ValueError("Cannot index with multidimensional key")
#    1112
# -> 1113                 return self._getitem_iterable(key, axis=axis)
#    1114
#    1115             # nested tuple slicing
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1051
#    1052         # A collection of keys
# -> 1053         keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1054         return self.obj._reindex_with_indexers(
#    1055             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1306             if missing == len(indexer):
#    1307                 axis_name = self.obj._get_axis_name(axis)
# -> 1308                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1309
#    1310             ax = self.obj._get_axis(axis)
#
# KeyError: "None of [Index(['Berkshire', 'Berkshire', 'Berkshire', 'Berkshire', 'Berkshire',\n       'Berkshire', 'Berkshire', 'Berkshire', 'Berkshire', 'Berkshire',\n       ...\n       'Suffolk', 'Suffolk', 'Suffolk', 'Suffolk', 'Suffolk', 'Suffolk',\n       'Suffolk', 'Suffolk', 'Suffolk', 'Suffolk'],\n      dtype='object', length=3160)] are in the [index]"

# %%
sns.lineplot(data=hunch.County, x='Report Date', y='avg_concentration', hue='City/Town')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2887-d0b7f0c5bbc0> in <module>
# ----> 1 sns.lineplot(data=hunch.County, x='Report Date', y='avg_concentration', hue='City/Town')
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     683
#     684     variables = _LinePlotter.get_semantics(locals())
# --> 685     p = _LinePlotter(
#     686         data=data, variables=variables,
#     687         estimator=estimator, ci=ci, n_boot=n_boot, seed=seed,
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in __init__(self, data, variables, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend)
#     365         )
#     366
# --> 367         super().__init__(data=data, variables=variables)
#     368
#     369         self.estimator = estimator
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in assign_variables(self, data, variables)
#     665         else:
#     666             self.input_format = "long"
# --> 667             plot_data, variables = self._assign_variables_longform(
#     668                 data, **variables,
#     669             )
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in _assign_variables_longform(self, data, **kwargs)
#     900
#     901                 err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 902                 raise ValueError(err)
#     903
#     904             else:
#
# ValueError: Could not interpret value `Report Date` for parameter `x`

# %%
type(hunch.County)
# Out:
# pandas.core.series.Series

# %%
hunch.set_index(['County', 'City/Town'], inplace=True)

# %%
hunch['month'] = hunch['Report Date'].dt.month

# %%
hunch.reset_index(inplace=True)

# %%
hunch.set_index('Report Date', inplace=True)

# %%
timeslice = pd.DataFrame(hunch.loc['2021-03-05':'2021-07-31'])
# Out:
# <ipython-input-1130-d6eeff41ef8c>:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   timeslice = pd.DataFrame(hunch.loc['2021-03-05':'2021-07-31'])

# %%
timeslice
# Out:
#                 County   City/Town       population Change Since Last Week  \
# Report Date
# 2021-03-18   Berkshire       Adams     50000-100000                  Lower
# 2021-03-18   Berkshire      Alford     50000-100000              No Change
# 2021-03-18   Berkshire      Becket     50000-100000                 Higher
# 2021-03-18   Berkshire    Cheshire     50000-100000                  Lower
# 2021-03-18   Berkshire  Clarksburg     50000-100000              No Change
# ...                ...         ...              ...                    ...
# 2021-06-03     Suffolk    Winthrop  2000000-5000000                  Lower
# 2021-06-10     Suffolk      Boston  2000000-5000000              No Change
# 2021-06-10     Suffolk     Chelsea  2000000-5000000                  Lower
# 2021-06-10     Suffolk      Revere  2000000-5000000                  Lower
# 2021-06-10     Suffolk    Winthrop  2000000-5000000                  Lower
#
#              Percent Positivity  avg_concentration  concentration_pct_change  \
# Report Date
# 2021-03-18             0.002841         170.369244                 28.333466
# 2021-03-18             0.000000         170.369244                  0.000000
# 2021-03-18             0.006410         170.369244                  0.000000
# 2021-03-18             0.003401         170.369244                  0.000000
# 2021-03-18             0.000000         170.369244                  0.000000
# ...                         ...                ...                       ...
# 2021-06-03             0.007618          28.980287                  0.000000
# 2021-06-10             0.004727          26.426384                 -8.812553
# 2021-06-10             0.008971          26.426384                  0.000000
# 2021-06-10             0.009459          26.426384                  0.000000
# 2021-06-10             0.006240          26.426384                  0.000000
#
#              month
# Report Date
# 2021-03-18       3
# 2021-03-18       3
# 2021-03-18       3
# 2021-03-18       3
# 2021-03-18       3
# ...            ...
# 2021-06-03       6
# 2021-06-10       6
# 2021-06-10       6
# 2021-06-10       6
# 2021-06-10       6
#
# [1697 rows x 8 columns]

# %%
timeslice['MA_6'] = timeslice.avg_concentration.rolling(window=3).mean().shift()
timeslice['MA_30'] = timeslice.avg_concentration.rolling(window=30).mean()

# %%
df1 = df.copy()
df1.set_index('Report Date', inplace=True)
df1['MA_5'] = df1.avg_concentration.rolling(window=5).mean().shift()
df1['MA_15'] = df1.avg_concentration.rolling(window=15).mean().shift()

# %%
df1[1:300:5]
# Out:
#             sampling_week    population                    per     County  \
# Report Date
# 2020-12-24     2020-12-23  50000-100000  2020-12-22/2020-12-28  Berkshire
# 2020-12-24     2020-12-23  50000-100000  2020-12-22/2020-12-28  Berkshire
# 2020-12-24     2020-12-23  50000-100000  2020-12-22/2020-12-28  Berkshire
# 2020-12-24     2020-12-23  50000-100000  2020-12-22/2020-12-28  Berkshire
# 2020-12-24     2020-12-23  50000-100000  2020-12-22/2020-12-28  Berkshire
# 2020-12-24     2020-12-23  50000-100000  2020-12-22/2020-12-28  Berkshire
# 2020-12-24     2020-12-23  50000-100000  2020-12-22/2020-12-28  Berkshire
# 2020-12-31     2020-12-30  50000-100000  2020-12-29/2021-01-04  Berkshire
# 2020-12-31     2020-12-30  50000-100000  2020-12-29/2021-01-04  Berkshire
# 2020-12-31     2020-12-30  50000-100000  2020-12-29/2021-01-04  Berkshire
# 2020-12-31     2020-12-30  50000-100000  2020-12-29/2021-01-04  Berkshire
# 2020-12-31     2020-12-30  50000-100000  2020-12-29/2021-01-04  Berkshire
# 2020-12-31     2020-12-30  50000-100000  2020-12-29/2021-01-04  Berkshire
# 2021-01-07     2021-01-06  50000-100000  2021-01-05/2021-01-11  Berkshire
# 2021-01-07     2021-01-06  50000-100000  2021-01-05/2021-01-11  Berkshire
# 2021-01-07     2021-01-06  50000-100000  2021-01-05/2021-01-11  Berkshire
# 2021-01-07     2021-01-06  50000-100000  2021-01-05/2021-01-11  Berkshire
# 2021-01-07     2021-01-06  50000-100000  2021-01-05/2021-01-11  Berkshire
# 2021-01-07     2021-01-06  50000-100000  2021-01-05/2021-01-11  Berkshire
# 2021-01-14     2021-01-13  50000-100000  2021-01-12/2021-01-18  Berkshire
# 2021-01-14     2021-01-13  50000-100000  2021-01-12/2021-01-18  Berkshire
# 2021-01-14     2021-01-13  50000-100000  2021-01-12/2021-01-18  Berkshire
# 2021-01-14     2021-01-13  50000-100000  2021-01-12/2021-01-18  Berkshire
# 2021-01-14     2021-01-13  50000-100000  2021-01-12/2021-01-18  Berkshire
# 2021-01-14     2021-01-13  50000-100000  2021-01-12/2021-01-18  Berkshire
# 2021-01-14     2021-01-13  50000-100000  2021-01-12/2021-01-18  Berkshire
# 2021-01-21     2021-01-20  50000-100000  2021-01-19/2021-01-25  Berkshire
# 2021-01-21     2021-01-20  50000-100000  2021-01-19/2021-01-25  Berkshire
# 2021-01-21     2021-01-20  50000-100000  2021-01-19/2021-01-25  Berkshire
# 2021-01-21     2021-01-20  50000-100000  2021-01-19/2021-01-25  Berkshire
# 2021-01-21     2021-01-20  50000-100000  2021-01-19/2021-01-25  Berkshire
# 2021-01-21     2021-01-20  50000-100000  2021-01-19/2021-01-25  Berkshire
# 2021-01-28     2021-01-27  50000-100000  2021-01-26/2021-02-01  Berkshire
# 2021-01-28     2021-01-27  50000-100000  2021-01-26/2021-02-01  Berkshire
# 2021-01-28     2021-01-27  50000-100000  2021-01-26/2021-02-01  Berkshire
# 2021-01-28     2021-01-27  50000-100000  2021-01-26/2021-02-01  Berkshire
# 2021-01-28     2021-01-27  50000-100000  2021-01-26/2021-02-01  Berkshire
# 2021-01-28     2021-01-27  50000-100000  2021-01-26/2021-02-01  Berkshire
# 2021-01-28     2021-01-27  50000-100000  2021-01-26/2021-02-01  Berkshire
# 2021-02-11     2021-02-10  50000-100000  2021-02-09/2021-02-15  Berkshire
# 2021-02-11     2021-02-10  50000-100000  2021-02-09/2021-02-15  Berkshire
# 2021-02-11     2021-02-10  50000-100000  2021-02-09/2021-02-15  Berkshire
# 2021-02-11     2021-02-10  50000-100000  2021-02-09/2021-02-15  Berkshire
# 2021-02-11     2021-02-10  50000-100000  2021-02-09/2021-02-15  Berkshire
# 2021-02-11     2021-02-10  50000-100000  2021-02-09/2021-02-15  Berkshire
# 2021-02-25     2021-02-24  50000-100000  2021-02-23/2021-03-01  Berkshire
# 2021-02-25     2021-02-24  50000-100000  2021-02-23/2021-03-01  Berkshire
# 2021-02-25     2021-02-24  50000-100000  2021-02-23/2021-03-01  Berkshire
# 2021-02-25     2021-02-24  50000-100000  2021-02-23/2021-03-01  Berkshire
# 2021-02-25     2021-02-24  50000-100000  2021-02-23/2021-03-01  Berkshire
# 2021-02-25     2021-02-24  50000-100000  2021-02-23/2021-03-01  Berkshire
# 2021-03-18     2021-03-17  50000-100000  2021-03-16/2021-03-22  Berkshire
# 2021-03-18     2021-03-17  50000-100000  2021-03-16/2021-03-22  Berkshire
# 2021-03-18     2021-03-17  50000-100000  2021-03-16/2021-03-22  Berkshire
# 2021-03-18     2021-03-17  50000-100000  2021-03-16/2021-03-22  Berkshire
# 2021-03-18     2021-03-17  50000-100000  2021-03-16/2021-03-22  Berkshire
# 2021-03-18     2021-03-17  50000-100000  2021-03-16/2021-03-22  Berkshire
# 2021-03-18     2021-03-17  50000-100000  2021-03-16/2021-03-22  Berkshire
# 2021-03-25     2021-03-24  50000-100000  2021-03-23/2021-03-29  Berkshire
# 2021-03-25     2021-03-24  50000-100000  2021-03-23/2021-03-29  Berkshire
#
#                     City/Town  Percent Positivity Change Since Last Week  \
# Report Date
# 2020-12-24             Alford            0.000000              No Change
# 2020-12-24           Egremont            0.000000                  Lower
# 2020-12-24       Lanesborough            0.036184                 Higher
# 2020-12-24        New Ashford            0.166667                 Higher
# 2020-12-24         Pittsfield            0.036335                  Lower
# 2020-12-24        Stockbridge            0.005556                  Lower
# 2020-12-24            Windsor            0.000000                  Lower
# 2020-12-31         Clarksburg            0.039604                 Higher
# 2020-12-31            Hancock            0.166667                  Lower
# 2020-12-31           Monterey            0.012821                  Lower
# 2020-12-31               Otis            0.074380                  Lower
# 2020-12-31              Savoy            0.018519                 Higher
# 2020-12-31   West Stockbridge            0.033784                 Higher
# 2021-01-07             Becket            0.039326                  Lower
# 2021-01-07            Florida            0.030303                 Higher
# 2021-01-07                Lee            0.099329                 Higher
# 2021-01-07    New Marlborough            0.067568                 Higher
# 2021-01-07           Richmond            0.042735                 Higher
# 2021-01-07          Tyringham            0.121212                 Higher
# 2021-01-14              Adams            0.048436                 Higher
# 2021-01-14             Dalton            0.047822                 Higher
# 2021-01-14           Hinsdale            0.067093                 Higher
# 2021-01-14   Mount Washington            0.000000              No Change
# 2021-01-14               Peru            0.135135                 Higher
# 2021-01-14          Sheffield            0.022403                  Lower
# 2021-01-14       Williamstown            0.008761                  Lower
# 2021-01-21           Cheshire            0.062814                  Lower
# 2021-01-21   Great Barrington            0.064605                 Higher
# 2021-01-21              Lenox            0.027123                 Higher
# 2021-01-21        North Adams            0.030346                  Lower
# 2021-01-21        Sandisfield            0.067901                  Lower
# 2021-01-21         Washington            0.047619                 Higher
# 2021-01-28             Alford            0.000000              No Change
# 2021-01-28           Egremont            0.010309                  Lower
# 2021-01-28       Lanesborough            0.016129                  Lower
# 2021-01-28        New Ashford            0.000000              No Change
# 2021-01-28         Pittsfield            0.049083                  Lower
# 2021-01-28        Stockbridge            0.022727                  Lower
# 2021-01-28            Windsor            0.096774                 Higher
# 2021-02-11         Clarksburg            0.016393                 Higher
# 2021-02-11            Hancock            0.200000                 Higher
# 2021-02-11           Monterey            0.000000                  Lower
# 2021-02-11               Otis            0.033058                  Lower
# 2021-02-11              Savoy            0.000000                  Lower
# 2021-02-11   West Stockbridge            0.006211                  Lower
# 2021-02-25             Becket            0.013158                 Higher
# 2021-02-25            Florida            0.000000              No Change
# 2021-02-25                Lee            0.013384                 Higher
# 2021-02-25    New Marlborough            0.000000              No Change
# 2021-02-25           Richmond            0.025424                 Higher
# 2021-02-25          Tyringham            0.000000              No Change
# 2021-03-18              Adams            0.002841                  Lower
# 2021-03-18             Dalton            0.017884                 Higher
# 2021-03-18           Hinsdale            0.056604                 Higher
# 2021-03-18   Mount Washington            0.000000              No Change
# 2021-03-18               Peru            0.000000              No Change
# 2021-03-18          Sheffield            0.005814                 Higher
# 2021-03-18       Williamstown            0.000917              No Change
# 2021-03-25           Cheshire            0.009646                 Higher
# 2021-03-25   Great Barrington            0.007714              No Change
#
#              avg_concentration        MA_5       MA_15
# Report Date
# 2020-12-24          420.042264         NaN         NaN
# 2020-12-24          420.042264  420.042264         NaN
# 2020-12-24          420.042264  420.042264         NaN
# 2020-12-24          420.042264  420.042264  420.042264
# 2020-12-24          420.042264  420.042264  420.042264
# 2020-12-24          420.042264  420.042264  420.042264
# 2020-12-24          420.042264  420.042264  420.042264
# 2020-12-31          805.950096  728.768530  522.951019
# 2020-12-31          805.950096  805.950096  651.586963
# 2020-12-31          805.950096  805.950096  780.222908
# 2020-12-31          805.950096  805.950096  805.950096
# 2020-12-31          805.950096  805.950096  805.950096
# 2020-12-31          805.950096  805.950096  805.950096
# 2021-01-07          946.668202  862.237339  824.712510
# 2021-01-07          946.668202  946.668202  871.618546
# 2021-01-07          946.668202  946.668202  918.524581
# 2021-01-07          946.668202  946.668202  946.668202
# 2021-01-07          946.668202  946.668202  946.668202
# 2021-01-07          946.668202  946.668202  946.668202
# 2021-01-14          832.925893  946.668202  946.668202
# 2021-01-14          832.925893  832.925893  908.754099
# 2021-01-14          832.925893  832.925893  870.839996
# 2021-01-14          832.925893  832.925893  832.925893
# 2021-01-14          832.925893  832.925893  832.925893
# 2021-01-14          832.925893  832.925893  832.925893
# 2021-01-14          832.925893  832.925893  832.925893
# 2021-01-21          406.299685  576.950168  747.600652
# 2021-01-21          406.299685  406.299685  605.391916
# 2021-01-21          406.299685  406.299685  463.183180
# 2021-01-21          406.299685  406.299685  406.299685
# 2021-01-21          406.299685  406.299685  406.299685
# 2021-01-21          406.299685  406.299685  406.299685
# 2021-01-28          147.432108  354.526170  389.041847
# 2021-01-28          147.432108  147.432108  302.752654
# 2021-01-28          147.432108  147.432108  216.463462
# 2021-01-28          147.432108  147.432108  147.432108
# 2021-01-28          147.432108  147.432108  147.432108
# 2021-01-28          147.432108  147.432108  147.432108
# 2021-01-28          147.432108  147.432108  147.432108
# 2021-02-11           66.858163   82.972952  125.945723
# 2021-02-11           66.858163   66.858163   99.087741
# 2021-02-11           66.858163   66.858163   72.229759
# 2021-02-11           66.858163   66.858163   66.858163
# 2021-02-11           66.858163   66.858163   66.858163
# 2021-02-11           66.858163   66.858163   66.858163
# 2021-02-25          132.755118   93.216945   75.644423
# 2021-02-25          132.755118  132.755118   97.610075
# 2021-02-25          132.755118  132.755118  119.575727
# 2021-02-25          132.755118  132.755118  132.755118
# 2021-02-25          132.755118  132.755118  132.755118
# 2021-02-25          132.755118  132.755118  132.755118
# 2021-03-18          170.369244  132.755118  132.755118
# 2021-03-18          170.369244  170.369244  145.293160
# 2021-03-18          170.369244  170.369244  157.831202
# 2021-03-18          170.369244  170.369244  170.369244
# 2021-03-18          170.369244  170.369244  170.369244
# 2021-03-18          170.369244  170.369244  170.369244
# 2021-03-18          170.369244  170.369244  170.369244
# 2021-03-25          195.137153  185.229989  175.322826
# 2021-03-25          195.137153  195.137153  183.578795

# %%
plt.figure(figsize=(21,9))
plt.grid(True)
sns.lineplot(data = df, x=df1.index, 
             y=df1['avg_concentration'], 
             label='average concentration')
sns.lineplot(data = df, 
             x=df1.index, 
             y=df1['MA_5'], 
             label='Moving Average 6-Days')
sns.lineplot(data = df, 
             x=df1.index, 
             y=df1['MA_15'], 
             label='Moving Average 30-Days')
plt.legend()
plt.plot()
# Out:
# []

# %%
#No idea what this is for, delete
timeslice['change'] = np.log(timeslice['avg_concentration'] / timeslice['avg_concentration'].shift())
sns.lineplot(data=timeslice, x=timeslice.index, y=timeslice['change'], hue='County')
# Out:
# C:\Users\Aim\anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
#this is a rolling historical volatility, for a 7-day week, offset one day using .shift()
timeslice['Volatility'] = timeslice.change.rolling(7).std().shift(1)
timeslice['Volatility'].plot()
# Out:
# <AxesSubplot:xlabel='Report Date'>

# %%
timeslice['City/Town'].unique()
# Out:
# ['Adams', 'Alford', 'Becket', 'Cheshire', 'Clarksburg', ..., 'Nantucket', 'Boston', 'Chelsea', 'Revere', 'Winthrop']
# Length: 145
# Categories (145, object): ['Adams', 'Alford', 'Becket', 'Cheshire', ..., 'Boston', 'Chelsea', 'Revere', 'Winthrop']

# %%
#timeslice['Volatility'].plot()
Essex_slice_avg = timeslice.loc[timeslice['County']=='Essex', 'avg_concentration']
Essex_slice_volatility = timeslice.loc[timeslice['County'] =='Essex', 'Volatility']
#Essex_vol_drop =Essex_slice_volatility[:1]
#Essex_vol_series = pd.Series(~timeslice.isin(Essex_vol_drop))
fig, ax = plt.subplots(figsize=(21,9))

#sns.lineplot(data=Essex_slice_avg,
             #y=Essex_slice_avg.unique(), x=Essex_slice_avg.index.unique())
#ax2 = plt.twinx()
sns.lineplot(data=Essex_slice_volatility, y=Essex_slice_volatility.unique(), 
             x=Essex_slice_volatility.index, ci=None, )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2026-4100e2a58c7d> in <module>
#       9              #y=Essex_slice_avg.unique(), x=Essex_slice_avg.index.unique())
#      10 #ax2 = plt.twinx()
# ---> 11 sns.lineplot(data=Essex_slice_volatility, y=Essex_slice_volatility.unique(),
#      12              x=Essex_slice_volatility.index, ci=None, )
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     683
#     684     variables = _LinePlotter.get_semantics(locals())
# --> 685     p = _LinePlotter(
#     686         data=data, variables=variables,
#     687         estimator=estimator, ci=ci, n_boot=n_boot, seed=seed,
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in __init__(self, data, variables, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend)
#     365         )
#     366
# --> 367         super().__init__(data=data, variables=variables)
#     368
#     369         self.estimator = estimator
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in assign_variables(self, data, variables)
#     665         else:
#     666             self.input_format = "long"
# --> 667             plot_data, variables = self._assign_variables_longform(
#     668                 data, **variables,
#     669             )
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in _assign_variables_longform(self, data, **kwargs)
#     924         # Construct a tidy plot DataFrame. This will convert a number of
#     925         # types automatically, aligning on index in case of pandas objects
# --> 926         plot_data = pd.DataFrame(plot_data)
#     927
#     928         # Reduce the variables dictionary to fields with valid data
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      78         # figure out the index, if necessary
#      79         if index is None:
# ---> 80             index = extract_index(arrays)
#      81         else:
#      82             index = ensure_index(index)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     399             lengths = list(set(raw_lengths))
#     400             if len(lengths) > 1:
# --> 401                 raise ValueError("arrays must all be same length")
#     402
#     403             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
len(Essex_slice_avg.unique())
# Out:
# 12

# %%
timeslice.keys()
# Out:
# Index(['County', 'City/Town', 'population', 'Change Since Last Week',
#        'Percent Positivity', 'avg_concentration', 'concentration_pct_change',
#        'month', 'MA_6', 'MA_30', 'change', 'Volatility'],
#       dtype='object')

# %%
Essex_slice_volatility = pd.DataFrame(timeslice.loc[timeslice['County']=='Essex'])
Essex_slice_volatility
# Out:
#             County     City/Town   population Change Since Last Week  \
# Report Date
# 2021-03-11   Essex      Amesbury  20000-50000                  Lower
# 2021-03-11   Essex       Andover  20000-50000                  Lower
# 2021-03-11   Essex       Beverly  20000-50000                  Lower
# 2021-03-11   Essex       Boxford  20000-50000                 Higher
# 2021-03-11   Essex       Danvers  20000-50000                  Lower
# ...            ...           ...          ...                    ...
# 2021-06-10   Essex        Saugus  20000-50000              No Change
# 2021-06-10   Essex    Swampscott  20000-50000                  Lower
# 2021-06-10   Essex     Topsfield  20000-50000                  Lower
# 2021-06-10   Essex        Wenham  20000-50000              No Change
# 2021-06-10   Essex  West Newbury  20000-50000              No Change
#
#              Percent Positivity  avg_concentration  concentration_pct_change  \
# Report Date
# 2021-03-11             0.014015       1.233615e+02                106.057273
# 2021-03-11             0.016760       1.233615e+02                  0.000000
# 2021-03-11             0.014947       1.233615e+02                  0.000000
# 2021-03-11             0.027607       1.233615e+02                  0.000000
# 2021-03-11             0.022838       1.233615e+02                  0.000000
# ...                         ...                ...                       ...
# 2021-06-10             0.012552       9.947598e-14                  0.000000
# 2021-06-10             0.001242       9.947598e-14                  0.000000
# 2021-06-10             0.002755       9.947598e-14                  0.000000
# 2021-06-10             0.000000       9.947598e-14                  0.000000
# 2021-06-10             0.000000       9.947598e-14                  0.000000
#
#              month          MA_6         MA_30    change  Volatility
# Report Date
# 2021-03-11       3  1.370887e+01  1.736396e+01  2.197076    0.000000
# 2021-03-11       3  5.025974e+01  2.101904e+01  0.000000    0.830417
# 2021-03-11       3  8.681061e+01  2.467413e+01  0.000000    0.830417
# 2021-03-11       3  1.233615e+02  2.832922e+01  0.000000    0.830417
# 2021-03-11       3  1.233615e+02  3.198430e+01  0.000000    0.830417
# ...            ...           ...           ...       ...         ...
# 2021-06-10       6  9.947598e-14  9.947598e-14  0.000000    0.000000
# 2021-06-10       6  9.947598e-14  9.947598e-14  0.000000    0.000000
# 2021-06-10       6  9.947598e-14  9.947598e-14  0.000000    0.000000
# 2021-06-10       6  9.947598e-14  9.947598e-14  0.000000    0.000000
# 2021-06-10       6  9.947598e-14  9.947598e-14  0.000000    0.000000
#
# [408 rows x 12 columns]

# %%
mask_volatility = Essex_slice_volatility.index.duplicated(keep='first')
slice_test = pd.DataFrame(Essex_slice_volatility[mask_volatility])
sns.lineplot(data=slice_test, x=slice_test.index, y='avg_concentration')
# Out:
# <AxesSubplot:xlabel='Report Date', ylabel='avg_concentration'>

# %%
a = pd.Series(slice_test['Volatility'].unique())
b = pd.Series(slice_test.index.unique())
sns.lineplot(data=slice_test,x=b,y=a)
# Out:
# <AxesSubplot:xlabel='Report Date'>

# %%
timeslice.County.unique()
# Out:
# ['Berkshire', 'Essex', 'Hampshire', 'Middlesex', 'Nantucket', 'Suffolk']
# Categories (6, object): ['Berkshire', 'Essex', 'Hampshire', 'Middlesex', 'Nantucket', 'Suffolk']

# %%
county_list = []
fig, ax = plt.subplots(figsize=(16,9))
for county in timeslice['County']:
    
    if county not in county_list:
        #print(county)
        county_list.append(county)
        county_slice = pd.DataFrame(timeslice[timeslice['County']==county])
        #sns.lineplot(data=county_slice, x=county_slice.index, y='avg_concentration')
        #ax2 = plt.twinx()
        sns.lineplot(data=county_slice, x=county_slice.index, y='Volatility')

# %%
timeslice[timeslice['County'] == 'Suffolk']
# Out:
#               County City/Town       population Change Since Last Week  \
# Report Date
# 2021-03-11   Suffolk    Boston  2000000-5000000              No Change
# 2021-03-11   Suffolk   Chelsea  2000000-5000000                  Lower
# 2021-03-11   Suffolk    Revere  2000000-5000000                 Higher
# 2021-03-11   Suffolk  Winthrop  2000000-5000000                  Lower
# 2021-03-18   Suffolk    Boston  2000000-5000000              No Change
# 2021-03-18   Suffolk   Chelsea  2000000-5000000                  Lower
# 2021-03-18   Suffolk    Revere  2000000-5000000                 Higher
# 2021-03-18   Suffolk  Winthrop  2000000-5000000                 Higher
# 2021-03-25   Suffolk    Boston  2000000-5000000              No Change
# 2021-03-25   Suffolk   Chelsea  2000000-5000000                  Lower
# 2021-03-25   Suffolk    Revere  2000000-5000000                  Lower
# 2021-03-25   Suffolk  Winthrop  2000000-5000000                  Lower
# 2021-04-01   Suffolk    Boston  2000000-5000000                 Higher
# 2021-04-01   Suffolk   Chelsea  2000000-5000000                 Higher
# 2021-04-01   Suffolk    Revere  2000000-5000000                 Higher
# 2021-04-01   Suffolk  Winthrop  2000000-5000000                 Higher
# 2021-04-08   Suffolk    Boston  2000000-5000000                 Higher
# 2021-04-08   Suffolk   Chelsea  2000000-5000000                 Higher
# 2021-04-08   Suffolk    Revere  2000000-5000000                 Higher
# 2021-04-08   Suffolk  Winthrop  2000000-5000000                 Higher
# 2021-04-15   Suffolk    Boston  2000000-5000000              No Change
# 2021-04-15   Suffolk   Chelsea  2000000-5000000                 Higher
# 2021-04-15   Suffolk    Revere  2000000-5000000                 Higher
# 2021-04-15   Suffolk  Winthrop  2000000-5000000                  Lower
# 2021-04-22   Suffolk    Boston  2000000-5000000                  Lower
# 2021-04-22   Suffolk   Chelsea  2000000-5000000                 Higher
# 2021-04-22   Suffolk    Revere  2000000-5000000                  Lower
# 2021-04-22   Suffolk  Winthrop  2000000-5000000                  Lower
# 2021-04-29   Suffolk    Boston  2000000-5000000                  Lower
# 2021-04-29   Suffolk   Chelsea  2000000-5000000                  Lower
# 2021-04-29   Suffolk    Revere  2000000-5000000                  Lower
# 2021-04-29   Suffolk  Winthrop  2000000-5000000                 Higher
# 2021-05-06   Suffolk    Boston  2000000-5000000                  Lower
# 2021-05-06   Suffolk   Chelsea  2000000-5000000                  Lower
# 2021-05-06   Suffolk    Revere  2000000-5000000                  Lower
# 2021-05-06   Suffolk  Winthrop  2000000-5000000                  Lower
# 2021-05-13   Suffolk    Boston  2000000-5000000                  Lower
# 2021-05-13   Suffolk   Chelsea  2000000-5000000                  Lower
# 2021-05-13   Suffolk    Revere  2000000-5000000                  Lower
# 2021-05-13   Suffolk  Winthrop  2000000-5000000                  Lower
# 2021-05-20   Suffolk    Boston  2000000-5000000              No Change
# 2021-05-20   Suffolk   Chelsea  2000000-5000000                  Lower
# 2021-05-20   Suffolk    Revere  2000000-5000000                  Lower
# 2021-05-20   Suffolk  Winthrop  2000000-5000000                  Lower
# 2021-05-27   Suffolk    Boston  2000000-5000000                  Lower
# 2021-05-27   Suffolk   Chelsea  2000000-5000000                  Lower
# 2021-05-27   Suffolk    Revere  2000000-5000000                  Lower
# 2021-05-27   Suffolk  Winthrop  2000000-5000000                  Lower
# 2021-06-03   Suffolk    Boston  2000000-5000000                  Lower
# 2021-06-03   Suffolk   Chelsea  2000000-5000000                  Lower
# 2021-06-03   Suffolk    Revere  2000000-5000000                  Lower
# 2021-06-03   Suffolk  Winthrop  2000000-5000000                  Lower
# 2021-06-10   Suffolk    Boston  2000000-5000000              No Change
# 2021-06-10   Suffolk   Chelsea  2000000-5000000                  Lower
# 2021-06-10   Suffolk    Revere  2000000-5000000                  Lower
# 2021-06-10   Suffolk  Winthrop  2000000-5000000                  Lower
#
#              Percent Positivity  avg_concentration  concentration_pct_change  \
# Report Date
# 2021-03-11             0.011563         331.241988                  6.874861
# 2021-03-11             0.031512         331.241988                  0.000000
# 2021-03-11             0.041203         331.241988                  0.000000
# 2021-03-11             0.023910         331.241988                  0.000000
# 2021-03-18             0.011139         329.239057                 -0.604673
# 2021-03-18             0.023798         329.239057                  0.000000
# 2021-03-18             0.042112         329.239057                  0.000000
# 2021-03-18             0.025974         329.239057                  0.000000
# 2021-03-25             0.011235         337.900008                  2.630596
# 2021-03-25             0.022304         337.900008                  0.000000
# 2021-03-25             0.037517         337.900008                  0.000000
# 2021-03-25             0.023501         337.900008                  0.000000
# 2021-04-01             0.014277         332.091592                 -1.718975
# 2021-04-01             0.025677         332.091592                  0.000000
# 2021-04-01             0.038695         332.091592                  0.000000
# 2021-04-01             0.027900         332.091592                  0.000000
# 2021-04-08             0.016919         312.506328                 -5.897549
# 2021-04-08             0.031136         312.506328                  0.000000
# 2021-04-08             0.044166         312.506328                  0.000000
# 2021-04-08             0.036770         312.506328                  0.000000
# 2021-04-15             0.016136         271.280005                -13.192156
# 2021-04-15             0.038308         271.280005                  0.000000
# 2021-04-15             0.048151         271.280005                  0.000000
# 2021-04-15             0.033541         271.280005                  0.000000
# 2021-04-22             0.013682         209.239652                -22.869490
# 2021-04-22             0.046336         209.239652                  0.000000
# 2021-04-22             0.046802         209.239652                  0.000000
# 2021-04-22             0.029919         209.239652                  0.000000
# 2021-04-29             0.010899         146.570424                -29.950933
# 2021-04-29             0.045088         146.570424                  0.000000
# 2021-04-29             0.044076         146.570424                  0.000000
# 2021-04-29             0.033694         146.570424                  0.000000
# 2021-05-06             0.009530         102.059487                -30.368293
# 2021-05-06             0.032484         102.059487                  0.000000
# 2021-05-06             0.035883         102.059487                  0.000000
# 2021-05-06             0.025697         102.059487                  0.000000
# 2021-05-13             0.008657          69.625957                -31.779045
# 2021-05-13             0.026228          69.625957                  0.000000
# 2021-05-13             0.027851          69.625957                  0.000000
# 2021-05-13             0.013639          69.625957                  0.000000
# 2021-05-20             0.007727          50.628972                -27.284344
# 2021-05-20             0.024030          50.628972                  0.000000
# 2021-05-20             0.023110          50.628972                  0.000000
# 2021-05-20             0.011771          50.628972                  0.000000
# 2021-05-27             0.006846          38.508182                -23.940422
# 2021-05-27             0.022394          38.508182                  0.000000
# 2021-05-27             0.019318          38.508182                  0.000000
# 2021-05-27             0.009242          38.508182                  0.000000
# 2021-06-03             0.005316          28.980287                -24.742523
# 2021-06-03             0.016758          28.980287                  0.000000
# 2021-06-03             0.013505          28.980287                  0.000000
# 2021-06-03             0.007618          28.980287                  0.000000
# 2021-06-10             0.004727          26.426384                 -8.812553
# 2021-06-10             0.008971          26.426384                  0.000000
# 2021-06-10             0.009459          26.426384                  0.000000
# 2021-06-10             0.006240          26.426384                  0.000000
#
#              month        MA_6       MA_30    change  Volatility
# Report Date
# 2021-03-11       3    7.367943  141.520346       inf         NaN
# 2021-03-11       3  110.737750  152.548168  0.000000         NaN
# 2021-03-11       3  220.827992  163.575990  0.000000         NaN
# 2021-03-11       3  331.241988  174.603813  0.000000         NaN
# 2021-03-18       3  331.241988  185.564871 -0.006065         NaN
# 2021-03-18       3  330.574345  196.525929  0.000000         NaN
# 2021-03-18       3  329.906701  207.486987  0.000000         NaN
# 2021-03-18       3  329.239057  218.448045  0.000000         NaN
# 2021-03-25       3  329.239057  229.697801  0.025966    0.002292
# 2021-03-25       3  332.126041  240.947558  0.000000    0.010444
# 2021-03-25       3  335.013024  252.197314  0.000000    0.010444
# 2021-03-25       3  337.900008  263.447071  0.000000    0.010444
# 2021-04-01       4  337.900008  274.503213 -0.017339    0.009814
# 2021-04-01       4  335.963869  285.559356  0.000000    0.012677
# 2021-04-01       4  334.027731  296.615498  0.000000    0.012677
# 2021-04-01       4  332.091592  307.671641  0.000000    0.012677
# 2021-04-08       4  332.091592  318.074941 -0.060786    0.006554
# 2021-04-08       4  325.563171  314.186571  0.000000    0.022817
# 2021-04-08       4  319.034749  307.967706  0.000000    0.022817
# 2021-04-08       4  312.506328  297.385034  0.000000    0.022817
# 2021-04-15       4  312.506328  283.226655 -0.141473    0.022975
# 2021-04-15       4  298.764220  271.373177  0.000000    0.054567
# 2021-04-15       4  285.022113  263.601225  0.000000    0.054567
# 2021-04-15       4  271.280005  263.922240  0.000000    0.054567
# 2021-04-22       4  271.280005  266.238201 -0.259671    0.053472
# 2021-04-22       4  250.599887  270.907596  0.000000    0.103647
# 2021-04-22       4  229.919770  276.895290  0.000000    0.103647
# 2021-04-22       4  209.239652  283.165526  0.000000    0.103647
# 2021-04-29       4  209.239652  288.018832 -0.355974    0.098147
# 2021-04-29       4  188.349909  292.904512  0.000000    0.152753
# 2021-04-29       4  167.460167  286.748794  0.000000    0.152753
# 2021-04-29       4  146.570424  280.593075  0.000000    0.152753
# 2021-05-06       5  146.570424  272.953658 -0.361950    0.134546
# 2021-05-06       5  131.733445  265.314241  0.000000    0.175164
# 2021-05-06       5  116.896466  257.741589  0.000000    0.175164
# 2021-05-06       5  102.059487  250.168937  0.000000    0.175164
# 2021-05-13       5  102.059487  241.515167 -0.382418    0.136804
# 2021-05-13       5   91.248310  232.861397  0.000000    0.181703
# 2021-05-13       5   80.437134  223.918928  0.000000    0.181703
# 2021-05-13       5   69.625957  214.976460  0.000000    0.181703
# 2021-05-20       5   69.625957  205.400759 -0.318613    0.144541
# 2021-05-20       5   63.293628  195.825057  0.000000    0.172023
# 2021-05-20       5   56.961300  186.442970  0.000000    0.172023
# 2021-05-20       5   50.628972  177.060883  0.000000    0.172023
# 2021-05-27       5   50.628972  167.274769 -0.273653    0.120425
# 2021-05-27       5   46.588708  157.488655  0.000000    0.145080
# 2021-05-27       5   42.548445  148.355384  0.000000    0.145080
# 2021-05-27       5   38.508182  139.222112  0.000000    0.145080
# 2021-06-03       6   38.508182  129.771244 -0.284255    0.103431
# 2021-06-03       6   35.332217  120.320376  0.000000    0.136150
# 2021-06-03       6   32.156252  112.243719  0.000000    0.136150
# 2021-06-03       6   28.980287  104.167062  0.000000    0.136150
# 2021-06-10       6   28.980287   96.005274 -0.092253    0.107438
# 2021-06-10       6   28.128986   87.843487  0.000000    0.107285
# 2021-06-10       6   27.277685   81.749711  0.000000    0.107285
# 2021-06-10       6   26.426384   75.655936  0.000000    0.107285

# %%
timeslice_1 = timeslice.drop('City/Town', axis=1)

# %%
timeslice_1.index.unique()
# Out:
# DatetimeIndex(['2021-03-18', '2021-03-25', '2021-04-01', '2021-04-08',
#                '2021-04-15', '2021-04-22', '2021-04-29', '2021-05-06',
#                '2021-05-13', '2021-05-20', '2021-05-27', '2021-06-03',
#                '2021-03-11', '2021-06-10'],
#               dtype='datetime64[ns]', name='Report Date', freq=None)

# %% [markdown]
# Comparing volatility (which is a windowing function of the standard deviation of avg_concentration for a week, offset by 1 day)

# %%
non_null_volatility = pd.DataFrame(timeslice.loc[~(timeslice['Volatility'].isnull())])

# %%
test = pd.DataFrame(non_null_volatility.drop(columns=['City/Town', 'population', 'County', 'month']))
test = pd.get_dummies(test)

# %%
plt.figure(figsize=(16,9))
sns.heatmap(test.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(data=timeslice, x=timeslice.index, y='Volatility')
# Out:
# <AxesSubplot:xlabel='Report Date', ylabel='Volatility'>

# %%
len(df.avg_concentration)
# Out:
# 3162

# %%
#Autocorrelation implies that we can forecast the next value of the series from the last n_values of observations
#n_values depends on nlags param in .acf()
ac = sm.tsa.acf(pd.get_dummies(df['Change Since Last Week']), nlags=1, fft=False)
fig = tsaplots.plot_acf(ac)
plt.show()

# %% [markdown]
# 'Change in Last Week' could be a random walk, the acf shows the first 30 lags are significant.
# Can this be modeled? Maybe, but I need to test for stationarity.

# %%
ac = sm.tsa.acf(df['avg_concentration'], nlags=14, fft=False)
fig = tsaplots.plot_acf(ac)
plt.show()

# %%
#creating a list to use as a boolean comparison in a slice
my_slice = ['Report Date', 'County', 'City/Town', 'avg_concentration']

df.loc[:, my_slice]
# Out:
#      Report Date     County   City/Town  avg_concentration
# 0     2020-12-24  Berkshire       Adams         420.042264
# 1     2020-12-24  Berkshire      Alford         420.042264
# 2     2020-12-24  Berkshire      Becket         420.042264
# 3     2020-12-24  Berkshire    Cheshire         420.042264
# 4     2020-12-24  Berkshire  Clarksburg         420.042264
# ...          ...        ...         ...                ...
# 3157  2021-06-03    Suffolk    Winthrop          28.980287
# 3158  2021-06-10    Suffolk      Boston          26.426384
# 3159  2021-06-10    Suffolk     Chelsea          26.426384
# 3160  2021-06-10    Suffolk      Revere          26.426384
# 3161  2021-06-10    Suffolk    Winthrop          26.426384
#
# [3162 rows x 4 columns]

# %%
timeslice.loc[timeslice['City/Town'] == 'Cambridge', my_slice]
# Out:
#                 County  City/Town  avg_concentration
# Report Date
# 2021-03-11   Middlesex  Cambridge          90.325222
# 2021-03-18   Middlesex  Cambridge          77.073703
# 2021-03-25   Middlesex  Cambridge          73.749727
# 2021-04-01   Middlesex  Cambridge          74.709837
# 2021-04-08   Middlesex  Cambridge          83.873931
# 2021-04-15   Middlesex  Cambridge          70.660376
# 2021-04-22   Middlesex  Cambridge          60.537721
# 2021-04-29   Middlesex  Cambridge          29.108129
# 2021-05-06   Middlesex  Cambridge          19.159626
# 2021-05-13   Middlesex  Cambridge           9.094838
# 2021-05-20   Middlesex  Cambridge           7.686238
# 2021-05-27   Middlesex  Cambridge           4.834260
# 2021-06-03   Middlesex  Cambridge           2.343160
# 2021-06-10   Middlesex  Cambridge           0.407316

# %%
#I created this method because I found it tedious to keep on slicing city data using pandas .loc
#By using this method, I can call up the data using a dict indexing such as dict[city_name]
def extract_city_from_df(df, column, the_slice, dictionary):
    '''Extract specific slices based on the specified city'''
    for city in df[column].unique():
        #city_dict.get(df.loc[df[column] == city, the_slice], city)
        if the_slice == None:
            dictionary[city] = df.loc[df[column] == city].set_index('Report Date', drop=True).copy()
        else:
            dictionary[city] = df.loc[df[column] == city, the_slice].set_index('Report Date', drop=True).copy()
    print('There were {} cities extracted to the dictionary from the DataFrame'.format(len(city_dict.keys())))
    return dictionary

# %%
df1 = df.copy()
#this next line is an example of feature engineering?
df1['Percent Change'] = df1.avg_concentration.pct_change(periods=14)*100
df1['Diff'] = df1.avg_concentration.diff(periods=14).shift(7)

#I'm not sure what the moving average is really doing here
df1['rolling'] = df1.avg_concentration.rolling(30, center=True).mean().shift()
cities_list = {}
cities = extract_city_from_df(df1,'City/Town', None, city_dict)
# Out:
# There were 145 cities extracted to the dictionary from the DataFrame

# %%
for city in cities.keys():
    cities[city].dropna(inplace=True)

# %%
cities['Cambridge']
# Out:
#             sampling_week     population                    per     County  \
# Report Date
# 2020-12-24     2020-12-23  100000-200000  2020-12-22/2020-12-28  Middlesex
# 2020-12-31     2020-12-30  100000-200000  2020-12-29/2021-01-04  Middlesex
# 2021-01-07     2021-01-06  100000-200000  2021-01-05/2021-01-11  Middlesex
# 2021-01-14     2021-01-13  100000-200000  2021-01-12/2021-01-18  Middlesex
# 2021-01-21     2021-01-20  100000-200000  2021-01-19/2021-01-25  Middlesex
# 2021-01-28     2021-01-27  100000-200000  2021-01-26/2021-02-01  Middlesex
# 2021-02-04     2021-02-03  100000-200000  2021-02-02/2021-02-08  Middlesex
# 2021-02-11     2021-02-10  100000-200000  2021-02-09/2021-02-15  Middlesex
# 2021-02-18     2021-02-17  100000-200000  2021-02-16/2021-02-22  Middlesex
# 2021-02-25     2021-02-24  100000-200000  2021-02-23/2021-03-01  Middlesex
# 2021-03-04     2021-03-03  100000-200000  2021-03-02/2021-03-08  Middlesex
# 2021-03-11     2021-03-10  100000-200000  2021-03-09/2021-03-15  Middlesex
# 2021-03-18     2021-03-17  100000-200000  2021-03-16/2021-03-22  Middlesex
# 2021-03-25     2021-03-24  100000-200000  2021-03-23/2021-03-29  Middlesex
# 2021-04-01     2021-03-31  100000-200000  2021-03-30/2021-04-05  Middlesex
# 2021-04-08     2021-04-07  100000-200000  2021-04-06/2021-04-12  Middlesex
# 2021-04-15     2021-04-14  100000-200000  2021-04-13/2021-04-19  Middlesex
# 2021-04-22     2021-04-21  100000-200000  2021-04-20/2021-04-26  Middlesex
# 2021-04-29     2021-04-28  100000-200000  2021-04-27/2021-05-03  Middlesex
# 2021-05-06     2021-05-05  100000-200000  2021-05-04/2021-05-10  Middlesex
# 2021-05-13     2021-05-12  100000-200000  2021-05-11/2021-05-17  Middlesex
# 2021-05-20     2021-05-19  100000-200000  2021-05-18/2021-05-24  Middlesex
# 2021-05-27     2021-05-26  100000-200000  2021-05-25/2021-05-31  Middlesex
# 2021-06-03     2021-06-02  100000-200000  2021-06-01/2021-06-07  Middlesex
# 2021-06-10     2021-06-09    10000-20000  2021-06-08/2021-06-14  Middlesex
#
#              City/Town  Percent Positivity Change Since Last Week  \
# Report Date
# 2020-12-24   Cambridge            0.011819              No Change
# 2020-12-31   Cambridge            0.013198                 Higher
# 2021-01-07   Cambridge            0.017948                 Higher
# 2021-01-14   Cambridge            0.018063              No Change
# 2021-01-21   Cambridge            0.014909                  Lower
# 2021-01-28   Cambridge            0.013123                  Lower
# 2021-02-04   Cambridge            0.010584                  Lower
# 2021-02-11   Cambridge            0.008016                  Lower
# 2021-02-18   Cambridge            0.005258                  Lower
# 2021-02-25   Cambridge            0.004108                  Lower
# 2021-03-04   Cambridge            0.003858              No Change
# 2021-03-11   Cambridge            0.004452              No Change
# 2021-03-18   Cambridge            0.004508              No Change
# 2021-03-25   Cambridge            0.004263              No Change
# 2021-04-01   Cambridge            0.005575                 Higher
# 2021-04-08   Cambridge            0.005880              No Change
# 2021-04-15   Cambridge            0.005987              No Change
# 2021-04-22   Cambridge            0.005952              No Change
# 2021-04-29   Cambridge            0.004387                  Lower
# 2021-05-06   Cambridge            0.003229                  Lower
# 2021-05-13   Cambridge            0.002064                  Lower
# 2021-05-20   Cambridge            0.001149              No Change
# 2021-05-27   Cambridge            0.001064              No Change
# 2021-06-03   Cambridge            0.000970              No Change
# 2021-06-10   Cambridge            0.000934              No Change
#
#              avg_concentration  Percent Change        Diff     rolling
# Report Date
# 2020-12-24          454.722050      298.847061  340.712924  386.579465
# 2020-12-31          407.335752      -10.420937  -47.386298  416.813012
# 2021-01-07          330.828325      -18.782399  -76.507427  346.129810
# 2021-01-14          265.228983      -19.828817  -65.599342  278.348851
# 2021-01-21          260.880836       -1.639393   -4.348147  261.750465
# 2021-01-28          218.415714      -16.277594  -42.465122  226.908738
# 2021-02-04          165.075523      -24.421407  -53.340191  175.743561
# 2021-02-11           94.110223      -42.989596  -70.965299  108.303283
# 2021-02-18           85.526618       -9.120800   -8.583606   87.243339
# 2021-02-25           95.555588       11.726139   10.028970   93.549794
# 2021-03-04          108.200214       13.232744   12.644626  105.671289
# 2021-03-11           90.325222      -16.520292  -17.874991   93.900221
# 2021-03-18           77.073703      -14.670896  -13.251520   79.724007
# 2021-03-25           73.749727       -4.312724   -3.323976   74.414522
# 2021-04-01           74.709837        1.301850    0.960111   74.517815
# 2021-04-08           83.873931       12.266248    9.164094   82.041112
# 2021-04-15           70.660376      -15.754067  -13.213556   73.303087
# 2021-04-22           60.537721      -14.325787  -10.122655   62.562252
# 2021-04-29           29.108129      -51.917369  -31.429592   35.394047
# 2021-05-06           19.159626      -34.177749   -9.948503   21.149326
# 2021-05-13            9.094838      -52.531232  -10.064787   11.107796
# 2021-05-20            7.686238      -15.487909   -1.408600    7.967958
# 2021-05-27            4.834260      -37.104992   -2.851978    5.404656
# 2021-06-03            2.343160      -51.530119   -2.491100    2.841380
# 2021-06-10            0.407316      -82.616804   -1.935844    0.794485

# %%
def city_MA_plot(dataFrame_dict, city, est_color, compared_feature, start_slice, end_slice):
    '''This method is to easily plot avg_vconcentration against another feature from a dict of the df, 
        with a specific label and color and time slice
        
        Parameters:
        dataFrame_dict: a dictionary type containing k:v of city:wrangled df of city
        city: the specific city data you want to graph
        est_color: The color wished displayed for the compared feature
        compared_feature: what you want to graph against avg_concentration
        start_slice: (Optional) Can leave as None or ''. Where to start the timeslce
        end_slice: (Optional): Where to end the timeslice
        '''
    
    cities = dataFrame_dict
    
    #Filter 
    assert str(city) in cities.keys(), 'That city is not in the dictionary.'
    assert compared_feature in cities[city].columns, 'That feature does not exist in the dataframe.'
    
    if start_slice=='' or end_slice=='':
        sns.lineplot(data=cities[city], x='Report Date', 
                     y='avg_concentration')
        sns.lineplot(data=cities[city], x='Report Date', y=str(compared_feature), 
                     color=str(est_color), label=compared_feature)
            
    else:
        sns.lineplot(data=cities[city].loc[start_slice:end_slice], 
                     x='Report Date', y='avg_concentration')
        sns.lineplot(data=cities[city].loc[start_slice:end_slice], 
                     x='Report Date', y=str(compared_feature), 
                     color=str(est_color), label=compared_feature)
    plt.title('Average Concentration compared to ' + str(compared_feature) +  ' feature')

# %%
fig, ax = plt.subplots(figsize=(16,9))
city_MA_plot(cities, 'Cambridge', 'black', 'rolling', 'February 2021', 'August 2021')

# %%
assert "Bangkok" in cities.keys(), 'Nope'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-2772-a027fdbb782c> in <module>
# ----> 1 assert "Bangkok" in cities.keys(), 'Nope'
#
# AssertionError: Nope

# %%
for city in cities.keys():
    sns.lineplot(data=cities[city].loc['January 2021':'August 2021'], x='Report Date', y='avg_concentration')

# %%
for city in cities.keys():
    sns.lineplot(data=cities[city].loc['January 2021':'August 2021'], x='Report Date', y='Percent Change')

# %%
for city in cities.keys():
    sns.lineplot(data=cities[city].loc['January 2021':'August 2021'], x='Report Date', y='Diff')

# %%
cities['Adams']
# Out:
#              avg_concentration  Volatility Change Since Last Week
# Report Date
# 2021-03-18          170.369244         NaN                  Lower
# 2021-03-25          195.137153         0.0                 Higher
# 2021-04-01          196.736261         0.0                 Higher
# 2021-04-08          181.796497         0.0                 Higher
# 2021-04-15          164.592287         0.0                  Lower
# 2021-04-22           67.778658         0.0                  Lower
# 2021-04-29           48.927430         0.0                  Lower
# 2021-05-06           33.389947         0.0                  Lower
# 2021-05-13           38.753519         0.0                 Higher
# 2021-05-20           22.264048         0.0                 Higher
# 2021-05-27           25.235580         0.0                  Lower
# 2021-06-03           13.708868         0.0                  Lower

# %%
test_df = merged_df.set_index(['County', 'City/Town'])

# %%
test_df.loc[('Essex')]
# Out:
#              sampling_week  normalized_concentration_rolling_average  \
# City/Town
# Amesbury        2020-12-30                              7.919060e+02
# Andover         2020-12-30                              7.919060e+02
# Beverly         2020-12-30                              7.919060e+02
# Boxford         2020-12-30                              7.919060e+02
# Danvers         2020-12-30                              7.919060e+02
# ...                    ...                                       ...
# Saugus          2021-06-09                              9.947598e-14
# Swampscott      2021-06-09                              9.947598e-14
# Topsfield       2021-06-09                              9.947598e-14
# Wenham          2021-06-09                              9.947598e-14
# West Newbury    2021-06-09                              9.947598e-14
#
#                population                    per Percent Positivity  \
# City/Town
# Amesbury      20000-50000  2020-12-29/2021-01-04           0.078035
# Andover       20000-50000  2020-12-29/2021-01-04           0.058149
# Beverly       20000-50000  2020-12-29/2021-01-04           0.056247
# Boxford       20000-50000  2020-12-29/2021-01-04            0.04785
# Danvers       20000-50000  2020-12-29/2021-01-04           0.061004
# ...                   ...                    ...                ...
# Saugus        20000-50000  2021-06-08/2021-06-14           0.012552
# Swampscott    20000-50000  2021-06-08/2021-06-14           0.001242
# Topsfield     20000-50000  2021-06-08/2021-06-14           0.002755
# Wenham        20000-50000  2021-06-08/2021-06-14                  0
# West Newbury  20000-50000  2021-06-08/2021-06-14                  0
#
#              Change Since Last Week Report Date
# City/Town
# Amesbury                      Lower  2020-12-31
# Andover                   No Change  2020-12-31
# Beverly                      Higher  2020-12-31
# Boxford                      Higher  2020-12-31
# Danvers                   No Change  2020-12-31
# ...                             ...         ...
# Saugus                    No Change  2021-06-10
# Swampscott                    Lower  2021-06-10
# Topsfield                     Lower  2021-06-10
# Wenham                    No Change  2021-06-10
# West Newbury              No Change  2021-06-10
#
# [748 rows x 7 columns]

# %%
test_df.loc[('Berkshire', 'Adams')]
# Out:
# <ipython-input-1344-86a05fe9ef24>:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   test_df.loc[('Berkshire', 'Adams')]
#                     sampling_week  normalized_concentration_rolling_average  \
# County    City/Town
# Berkshire Adams        2020-12-23                                420.042264
#           Adams        2020-12-30                                805.950096
#           Adams        2021-01-06                                946.668202
#           Adams        2021-01-13                                832.925893
#           Adams        2021-01-20                                406.299685
#           Adams        2021-01-27                                147.432108
#           Adams        2021-02-10                                 66.858163
#           Adams        2021-02-24                                132.755118
#           Adams        2021-03-17                                170.369244
#           Adams        2021-03-24                                195.137153
#           Adams        2021-03-31                                196.736261
#           Adams        2021-04-07                                181.796497
#           Adams        2021-04-14                                164.592287
#           Adams        2021-04-21                                 67.778658
#           Adams        2021-04-28                                 48.927430
#           Adams        2021-05-05                                 33.389947
#           Adams        2021-05-12                                 38.753519
#           Adams        2021-05-19                                 22.264048
#           Adams        2021-05-26                                 25.235580
#           Adams        2021-06-02                                 13.708868
#
#                        population                    per Percent Positivity  \
# County    City/Town
# Berkshire Adams      50000-100000  2020-12-22/2020-12-28           0.028758
#           Adams      50000-100000  2020-12-29/2021-01-04           0.035211
#           Adams      50000-100000  2021-01-05/2021-01-11           0.039242
#           Adams      50000-100000  2021-01-12/2021-01-18           0.048436
#           Adams      50000-100000  2021-01-19/2021-01-25           0.044966
#           Adams      50000-100000  2021-01-26/2021-02-01           0.031579
#           Adams      50000-100000  2021-02-09/2021-02-15           0.038375
#           Adams      50000-100000  2021-02-23/2021-03-01           0.006878
#           Adams      50000-100000  2021-03-16/2021-03-22           0.002841
#           Adams      50000-100000  2021-03-23/2021-03-29           0.010568
#           Adams      50000-100000  2021-03-30/2021-04-05           0.031215
#           Adams      50000-100000  2021-04-06/2021-04-12           0.040541
#           Adams      50000-100000  2021-04-13/2021-04-19           0.035635
#           Adams      50000-100000  2021-04-20/2021-04-26           0.031042
#           Adams      50000-100000  2021-04-27/2021-05-03           0.028078
#           Adams      50000-100000  2021-05-04/2021-05-10           0.018116
#           Adams      50000-100000  2021-05-11/2021-05-17           0.028148
#           Adams      50000-100000  2021-05-18/2021-05-24           0.031348
#           Adams      50000-100000  2021-05-25/2021-05-31           0.016779
#           Adams      50000-100000  2021-06-01/2021-06-07           0.009728
#
#                     Change Since Last Week Report Date
# County    City/Town
# Berkshire Adams                      Lower  2020-12-24
#           Adams                     Higher  2020-12-31
#           Adams                     Higher  2021-01-07
#           Adams                     Higher  2021-01-14
#           Adams                      Lower  2021-01-21
#           Adams                      Lower  2021-01-28
#           Adams                     Higher  2021-02-11
#           Adams                      Lower  2021-02-25
#           Adams                      Lower  2021-03-18
#           Adams                     Higher  2021-03-25
#           Adams                     Higher  2021-04-01
#           Adams                     Higher  2021-04-08
#           Adams                      Lower  2021-04-15
#           Adams                      Lower  2021-04-22
#           Adams                      Lower  2021-04-29
#           Adams                      Lower  2021-05-06
#           Adams                     Higher  2021-05-13
#           Adams                     Higher  2021-05-20
#           Adams                      Lower  2021-05-27
#           Adams                      Lower  2021-06-03

# %%
test_df.loc['Essex' , 'normalized_concentration_rolling_average'].plot.hist()
# Out:
# <ipython-input-1362-2f3288ce5a47>:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   test_df.loc['Essex' , 'normalized_concentration_rolling_average'].plot.hist()
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.catplot(data=test_df, x='Report Date', y='Change Since Last Week')

# %%
def windowing_MA(datetime, series):
    '''A rolling window which will calculate the moving average of a Series.'''
    dt_Series = pd.Series(pd.date_range(start=datetime.min(), end=datetime.max(), freq='D'))
    apply_to_series =

# %% [markdown]
# stopped here to sleep. I think I am in a better position to do ARMA now.

# %%
sns.catplot(data = df, x='County', y='avg_concentration')

# %%
sns.catplot(data = df, x='Change Since Last Week', y='avg_concentration')

# %%
sns.boxplot(data=df, x='County', y='avg_concentration')
# Out:
# <AxesSubplot:xlabel='County', ylabel='avg_concentration'>

# %% [markdown]
# ## Notes to Luka for Review
#
# The three line plots seems to have some kind of time-series trend that are in tandem with each other.
#
# Thoughts on time-series possibilities:
# 1. AR, MA, or ARMA models
# 2. Auto-correlation whilst looking at various lag values
# 3. Probably should test for unit root stationarity.
#
# The scatter plots, while showing large variability, a regression line still showed some positive correlation.
#
# What I worry about is how those outliers seen in the scatterplots may be affecting the calculated correlation coefficients. Must discuss with Luka.
#
# Finally, I did some preprocessing ahead of schedule to see the correlation between 'Change Since Last Week' and the 'mwra_concentration' features. Whil they aren't the strongest, concentration hass the highest rated correlation coefficient.
#
# I think I will pursue with concentration and Change Since.
#
# ### Here are my Null and Alternate Hypothesis to test:
#
# #### H0: The concentration of covid-19 rna in sewage does not either Positivity Percentage or Change Since Last Week.
#
# #### H-Alternate: The concentration of Covid-19 rna surveilled in sewage does affect Positivity Percentage or Change Since Last Week.
#
#
# #### Discuss with Luka:
# Do I need to set my p-value here? Howabout the level of significance, or the power needed to support these hypotheses?

# %%
#Saving current df for next Capstone 2 Unit
df.to_pickle('Unit16FeatureEngineering.pkl') #Commenting out for Github commit

# %% [markdown]
# # Pre-processing (Unit 16.3)

# %% [markdown]
# ## Goals from the rubric:
# 1. Create dummy features
# 2. Scale standardization
# 3. Split data into training and testing subsets

# %% [markdown]
# ### Create Dummy features
# I did this earlier, and will copy the commented out code here for mentor review.

# %%
#Converted object types into categorical dtypes
'''
def conversion(df, conversion_list):
    '''Method to convert my features into their appropriate datatypes'''
    for list in conversion_list:
        for col in list:
            if col in int64_list:
                df[col] = df[col].astype('int64')
            if col in category_list:
                df[col] = df[col].astype('category')
            if col in float64_list:
                df[col] = df[col].astype('float64')
'''
# I converted the following features:
# Color, Change Since Last Week, Change in Last Week

#Created dummy variables for thes categorical features:
# Change Since Last Week and Change in Last Week

'''
test = pd.get_dummies(df['Change Since Last Week'], prefix='Since Last Week', prefix_sep='-')
test1 = pd.get_dummies(df['Change in Last Week'], prefix='In Last Week', prefix_sep='-')
'''

#Merged my main df with these two dummy-added dfs
'''
test_df = df.copy()
merged_test1 = pd.merge(test_df, test, how='inner', right_index=True, left_index=True)
merged_test = pd.merge(merged_test1, test1, how='inner', right_index=True, left_index=True)
'''

# Finally I updated the main dataframe
'''
df = merged_test
'''

# %%
#load pickle for this unit
with open('Unit16FeatureEngineering.pkl', 'rb') as f:
    df = pickle.load(f)
    
df.info()

# %%
#Since I've already pre-processed dummy variables for Change Since, and Change in, should drop those two features
#Also dropping colors
df.drop(columns=['Change in Last Week', 'Change Since Last Week', 'Color'], inplace=True)

# %%
df.info()

# %%
preprocessed_df = df.select_dtypes(exclude=['uint8'])

# %% [markdown]
# ## Have to partition the testing and training subsets.

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import random

#this split is to test out 'Percent Positivity'
independent_variables = [col for col in preprocessed_df.columns if col != 'Percent Positivity']
print(independent_variables)
X = df[independent_variables] #these are independent variables

y = df['Percent Positivity'] #this is what I want to predict (Dependent variable)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# %%
# From experience, I should check the shapes of the splits
# to see if they match dimensions

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

# %% [markdown]
# ### Before we test out any models, we should scale our features!

# %%
scaler = MinMaxScaler()
scaled_X_train= scaler.fit_transform(X_train)
scaled_X_test = scaler.fit_transform(X_test)

# %%
scaled_X_train.shape

# %%
#let's try some models!
from sklearn import linear_model

model = linear_model.LinearRegression()
model.fit(scaled_X_train,y_train)
y_pred = model.predict(X_test)

# %%
max(model.coef_)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mean_squared_error(y_test, y_pred)

# %%
r2_score(y_test, y_pred)

# %%
#yikes! Let's try a logistic regression to predict "Change Since Last Week"

no_int8_df = df.select_dtypes(exclude=['uint8']) #excludes all the dummy features
independent_variables = no_int8_df.columns

X = df[independent_variables] #these are independent variables
y = df['Since Last Week-Higher'] #this is what I want to predict (Dependent variable)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.22, random_state=0)
#X_train = X_train.values.reshape(-1, 1)
#X_test = X_test.values.reshape(-1,1)
scaler = MinMaxScaler()
scaled_X_train= scaler.fit_transform(X_train)
scaled_X_test = scaler.fit_transform(X_test)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

# %%
from sklearn.linear_model import LogisticRegressionCV 
model = LogisticRegressionCV(cv=5)
lr = model.fit(scaled_X_train, y_train)
y_pred = lr.predict(scaled_X_test)

# %%
np.sum(y_pred==y_test) / len(y_pred)

# %%
lr.coef_

# %%
y_pred

# %%
len(y_pred)

# %%
from sklearn.ensemble import RandomForestClassifier
